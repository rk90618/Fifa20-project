# %% [markdown]
# ## CAPSTONE PROJECT-4 :- PRCP-1004-Fifa20
#
# ## PROJECT TEAM ID :-  PTID-CDS-APR-24-1889

# %% [markdown]
# # 1.Busines Case:-
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:- Explore football skills and cluster football players based on their attributes.
#
# Task3:- Explore the data and attempt all the below asked questions in a
# step by step manner:
#
# ● Prepare a rank ordered list of top 10 countries with most players. Which
# countries are producing the most footballers that play at this level?
#
# ● Plot the distribution of overall rating vs. age of players. Interpret what is the
# age after which a player stops improving?
#
# ● Which type of offensive players tends to get paid the most: the striker, the
# right-winger, or the left-winger?

# %% [markdown]
# ## 1. Business case:

# %% [markdown]
# FIFA 20 is a football simulation game published by Electronic Arts as part of the long-running FIFA series. This is the 27th installment, released on September 27, 2019, for Microsoft Windows, PlayStation 4, Xbox One, and Nintendo Switch. Notably, it's the first FIFA game to skip an Xbox 360 version, and the first since FIFA 07 to not have a PlayStation 3 version. A new feature in this edition is VOLTA Football, which shifts from the traditional 11v11 format to smaller street and futsal-style games, reminiscent of the old FIFA Street series. In VOLTA, players can customize their characters, choosing from a variety of options including gender, clothing, footwear, hats, accessories, and tattoos. Following the conclusion of "The Journey" in FIFA 19, FIFA 20 introduces a new storyline mode set in the VOLTA world, allowing players to experience a narrative-driven progression with their custom character. There's also a brief appearance by Alex Hunter, a key figure from "The Journey," alongside his agent Beatriz Villanova.
#
# Additionally, the "players_20.csv" dataset offers insights into the Career Mode for FIFA 15 through FIFA 20, providing a chance to compare players' stats across these six versions of the game.

# %% [markdown]
# ## 2. Import Libraries:

# %%
# Loading the required liabries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from matplotlib import rcParams

# %% [markdown]
# ## 3. Load Dataset:

# %%
data = pd.read_csv("players_20.csv")
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1992-02-05        175         68      Brazil
# 3      1993-01-07        188         87    Slovenia
# 4      1991-01-07        175         74     Belgium
# ...           ...        ...        ...         ...
# 18273  1997-03-10        186         79    China PR
# 18274  1997-01-01        177         66    China PR
# 18275  2000-05-16        186         75    China PR
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 0                       FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2
# 1                           Juventus  ...  65+3  61+3  61+3  61+3  65+3  61+3
# 2                Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# 3                    Atlético Madrid  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4                        Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3
# ...                              ...  ...   ...   ...   ...   ...   ...   ...
# 18273               Beijing Renhe FC  ...  43+2  42+2  42+2  42+2  43+2  45+2
# 18274               Shanghai SIPG FC  ...  44+2  43+2  43+2  43+2  44+2  46+2
# 18275         Hebei China Fortune FC  ...  47+2  49+2  49+2  49+2  47+2  47+2
# 18276  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2  48+2  48+2
# 18277         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2  48+2  48+2
#
#         lcb    cb   rcb    rb
# 0      52+2  52+2  52+2  63+2
# 1      53+3  53+3  53+3  61+3
# 2      46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN
# 4      49+3  49+3  49+3  61+3
# ...     ...   ...   ...   ...
# 18273  46+2  46+2  46+2  45+2
# 18274  47+2  47+2  47+2  46+2
# 18275  49+2  49+2  49+2  47+2
# 18276  49+2  49+2  49+2  48+2
# 18277  50+2  50+2  50+2  48+2
#
# [18278 rows x 104 columns]

# %%
data.head(pd.set_option('display.max_columns',None))
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1992-02-05        175         68      Brazil
# 3      1993-01-07        188         87    Slovenia
# 4      1991-01-07        175         74     Belgium
# ...           ...        ...        ...         ...
# 18273  1997-03-10        186         79    China PR
# 18274  1997-01-01        177         66    China PR
# 18275  2000-05-16        186         75    China PR
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club  overall  potential  value_eur  wage_eur  \
# 0                       FC Barcelona       94         94   95500000    565000
# 1                           Juventus       93         93   58500000    405000
# 2                Paris Saint-Germain       92         92  105500000    290000
# 3                    Atlético Madrid       91         93   77500000    125000
# 4                        Real Madrid       91         91   90000000    470000
# ...                              ...      ...        ...        ...       ...
# 18273               Beijing Renhe FC       48         56      40000      2000
# 18274               Shanghai SIPG FC       48         56      40000      2000
# 18275         Hebei China Fortune FC       48         56      40000      1000
# 18276  Shanghai Greenland Shenhua FC       48         54      40000      1000
# 18277         Hebei China Fortune FC       48         51      40000      2000
#
#       player_positions preferred_foot  international_reputation  weak_foot  \
# 0           RW, CF, ST           Left                         5          4
# 1               ST, LW          Right                         5          4
# 2              LW, CAM          Right                         5          5
# 3                   GK          Right                         3          3
# 4               LW, CF          Right                         4          4
# ...                ...            ...                       ...        ...
# 18273               CB          Right                         1          3
# 18274               CB          Right                         1          2
# 18275               CM          Right                         1          2
# 18276               CM          Right                         1          2
# 18277               CM          Right                         1          3
#
#        skill_moves      work_rate   body_type real_face  release_clause_eur  \
# 0                4     Medium/Low       Messi       Yes         195800000.0
# 1                5       High/Low  C. Ronaldo       Yes          96500000.0
# 2                5    High/Medium      Neymar       Yes         195200000.0
# 3                1  Medium/Medium      Normal       Yes         164700000.0
# 4                4    High/Medium      Normal       Yes         184500000.0
# ...            ...            ...         ...       ...                 ...
# 18273            2    Medium/High      Normal        No             70000.0
# 18274            2  Medium/Medium      Normal        No             72000.0
# 18275            2     Low/Medium        Lean        No             70000.0
# 18276            2        Low/Low        Lean        No             70000.0
# 18277            2  Medium/Medium      Normal        No                 NaN
#
#                                              player_tags team_position  \
# 0      #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1      #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2      #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                    NaN            GK
# 4                        #Speedster, #Dribbler, #Acrobat            LW
# ...                                                  ...           ...
# 18273                                                NaN           RES
# 18274                                                NaN           SUB
# 18275                                                NaN           SUB
# 18276                                                NaN           SUB
# 18277                                                NaN           SUB
#
#        team_jersey_number      loaned_from      joined  contract_valid_until  \
# 0                    10.0              NaN  2004-07-01                2021.0
# 1                     7.0              NaN  2018-07-10                2022.0
# 2                    10.0              NaN  2017-08-03                2022.0
# 3                    13.0              NaN  2014-07-16                2023.0
# 4                     7.0              NaN  2019-07-01                2024.0
# ...                   ...              ...         ...                   ...
# 18273                36.0              NaN  2018-07-13                2019.0
# 18274                31.0              NaN  2019-02-01                2022.0
# 18275                38.0              NaN  2019-01-01                2019.0
# 18276                33.0              NaN  2019-02-01                2022.0
# 18277                37.0  Tianjin TEDA FC         NaN                2019.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 0                 NaN                   NaN  87.0      92.0     92.0
# 1                  LS                   7.0  90.0      93.0     82.0
# 2                  LW                  10.0  91.0      85.0     87.0
# 3                  GK                   1.0   NaN       NaN      NaN
# 4                  LF                  10.0  91.0      83.0     86.0
# ...               ...                   ...   ...       ...      ...
# 18273             NaN                   NaN  57.0      23.0     28.0
# 18274             NaN                   NaN  58.0      24.0     33.0
# 18275             NaN                   NaN  54.0      35.0     44.0
# 18276             NaN                   NaN  59.0      35.0     47.0
# 18277             NaN                   NaN  60.0      32.0     51.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0           96.0       39.0    66.0        NaN          NaN         NaN
# 1           89.0       35.0    78.0        NaN          NaN         NaN
# 2           95.0       32.0    58.0        NaN          NaN         NaN
# 3            NaN        NaN     NaN       87.0         92.0        78.0
# 4           94.0       35.0    66.0        NaN          NaN         NaN
# ...          ...        ...     ...        ...          ...         ...
# 18273       33.0       47.0    51.0        NaN          NaN         NaN
# 18274       35.0       48.0    48.0        NaN          NaN         NaN
# 18275       45.0       48.0    51.0        NaN          NaN         NaN
# 18276       47.0       45.0    52.0        NaN          NaN         NaN
# 18277       45.0       47.0    55.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning  \
# 0              NaN       NaN             NaN
# 1              NaN       NaN             NaN
# 2              NaN       NaN             NaN
# 3             89.0      52.0            90.0
# 4              NaN       NaN             NaN
# ...            ...       ...             ...
# 18273          NaN       NaN             NaN
# 18274          NaN       NaN             NaN
# 18275          NaN       NaN             NaN
# 18276          NaN       NaN             NaN
# 18277          NaN       NaN             NaN
#
#                                            player_traits  attacking_crossing  \
# 0      Beat Offside Trap, Argues with Officials, Earl...                  88
# 1      Long Throw-in, Selfish, Argues with Officials,...                  84
# 2      Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                             Flair, Acrobatic Clearance                  13
# 4      Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
# ...                                                  ...                 ...
# 18273                                                NaN                  21
# 18274                                                NaN                  24
# 18275                                                NaN                  32
# 18276                                                NaN                  39
# 18277                                                NaN                  44
#
#        attacking_finishing  attacking_heading_accuracy  \
# 0                       95                          70
# 1                       94                          89
# 2                       87                          62
# 3                       11                          15
# 4                       84                          61
# ...                    ...                         ...
# 18273                   17                          40
# 18274                   20                          42
# 18275                   33                          49
# 18276                   34                          47
# 18277                   30                          48
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 0                           92                 88               97
# 1                           83                 87               89
# 2                           87                 87               96
# 3                           43                 13               12
# 4                           89                 83               95
# ...                        ...                ...              ...
# 18273                       35                 27               24
# 18274                       43                 28               32
# 18275                       53                 32               40
# 18276                       54                 28               42
# 18277                       58                 25               40
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0               93                 94                  92                  96
# 1               81                 76                  77                  92
# 2               88                 87                  81                  95
# 3               13                 14                  40                  30
# 4               83                 79                  83                  94
# ...            ...                ...                 ...                 ...
# 18273           23                 21                  28                  35
# 18274           24                 29                  39                  31
# 18275           32                 32                  55                  49
# 18276           37                 39                  48                  49
# 18277           34                 35                  52                  46
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         91                     84                93
# 1                         89                     91                87
# 2                         94                     89                96
# 3                         43                     60                67
# 4                         94                     88                95
# ...                      ...                    ...               ...
# 18273                     56                     58                45
# 18274                     55                     61                43
# 18275                     55                     54                52
# 18276                     55                     63                55
# 18277                     54                     64                52
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                      95                95                86             68
# 1                      96                71                95             95
# 2                      92                84                80             61
# 3                      88                49                59             78
# 4                      90                94                82             56
# ...                   ...               ...               ...            ...
# 18273                  40                73                36             70
# 18274                  41                76                33             72
# 18275                  52                57                48             60
# 18276                  54                59                46             61
# 18277                  49                71                41             64
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0                 75              68                94                    48
# 1                 85              78                93                    63
# 2                 81              49                84                    51
# 3                 41              78                12                    34
# 4                 84              63                80                    54
# ...              ...             ...               ...                   ...
# 18273             60              47                16                    46
# 18274             55              44                20                    42
# 18275             50              51                26                    50
# 18276             42              55                28                    57
# 18277             40              61                30                    54
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           40                     94                94
# 1                           29                     95                82
# 2                           36                     87                90
# 3                           19                     11                65
# 4                           41                     87                89
# ...                        ...                    ...               ...
# 18273                       48                     28                25
# 18274                       49                     23                25
# 18275                       45                     38                38
# 18276                       49                     31                48
# 18277                       47                     29                52
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       75                   96                 33
# 1                       85                   95                 28
# 2                       90                   94                 27
# 3                       11                   68                 27
# 4                       88                   91                 34
# ...                    ...                  ...                ...
# 18273                   39                   41                 45
# 18274                   37                   35                 42
# 18275                   36                   39                 46
# 18276                   36                   40                 39
# 18277                   38                   42                 52
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             37                        26
# 1                             32                        24
# 2                             26                        29
# 3                             12                        18
# 4                             27                        22
# ...                          ...                       ...
# 18273                         50                        52
# 18274                         53                        57
# 18275                         52                        46
# 18276                         44                        54
# 18277                         42                        48
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 2                       9                     9                   15
# 3                      87                    92                   78
# 4                      11                    12                    6
# ...                   ...                   ...                  ...
# 18273                   5                     5                   13
# 18274                  13                     6                   14
# 18275                   7                     8                   10
# 18276                  14                     9                   13
# 18277                   8                    12                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 0                           14                     8  89+2  89+2  89+2  93+2
# 1                           14                    11  91+3  91+3  91+3  89+3
# 2                           15                    11  84+3  84+3  84+3  90+3
# 3                           90                    89   NaN   NaN   NaN   NaN
# 4                            8                     8  83+3  83+3  83+3  89+3
# ...                        ...                   ...   ...   ...   ...   ...
# 18273                        5                    14  32+2  32+2  32+2  31+2
# 18274                       11                     9  33+2  33+2  33+2  33+2
# 18275                        6                    14  43+2  43+2  43+2  43+2
# 18276                       13                    13  43+2  43+2  43+2  45+2
# 18277                        9                    10  42+2  42+2  42+2  44+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0      93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2  87+2  87+2  87+2  92+2
# 1      90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3  81+3  88+3
# 2      89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3  82+3  82+3  82+3  89+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  83+3  83+3  83+3  89+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18273  31+2  31+2  31+2  31+2  31+2  31+2  31+2  33+2  33+2  33+2  33+2  33+2
# 18274  32+2  32+2  32+2  33+2  33+2  33+2  33+2  35+2  36+2  36+2  36+2  35+2
# 18275  43+2  43+2  43+2  43+2  44+2  44+2  44+2  45+2  46+2  46+2  46+2  45+2
# 18276  44+2  44+2  44+2  45+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
# 18277  43+2  43+2  43+2  44+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0      68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1      65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2      66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18273  43+2  42+2  42+2  42+2  43+2  45+2  46+2  46+2  46+2  45+2
# 18274  44+2  43+2  43+2  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  47+2  49+2  49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  49+2  49+2  49+2  48+2  48+2  50+2  50+2  50+2  48+2
#
# [18278 rows x 104 columns]

# %% [markdown]
# # 4. Basic Checks:

# %%
# Check shape:
data.shape
# Out:
# (18278, 104)

# %%
# Check dtypes:
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
# Check unique categories present in the data:
for i in  data:
    print(i, data[i].unique())
    print(data[i].value_counts())
    print("*************************")
# Out:
# sofifa_id [158023  20801 190871 ... 252332 251110 233449]
# 158023    1
# 247213    1
# 237712    1
# 235633    1
# 252324    1
#          ..
# 202474    1
# 203398    1
# 203751    1
# 203875    1
# 233449    1
# Name: sofifa_id, Length: 18278, dtype: int64
# *************************
# player_url ['https://sofifa.com/player/158023/lionel-messi/20/159586'
#  'https://sofifa.com/player/20801/c-ronaldo-dos-santos-aveiro/20/159586'
#  'https://sofifa.com/player/190871/neymar-da-silva-santos-jr/20/159586'
#  ... 'https://sofifa.com/player/252332/wei-zhang/20/159586'
#  'https://sofifa.com/player/251110/haijian-wang/20/159586'
#  'https://sofifa.com/player/233449/ximing-pan/20/159586']
# https://sofifa.com/player/158023/lionel-messi/20/159586              1
# https://sofifa.com/player/247213/sibiry-keita/20/159586              1
# https://sofifa.com/player/237712/valentin-castellanos/20/159586      1
# https://sofifa.com/player/235633/yehvann-diouf/20/159586             1
# https://sofifa.com/player/252324/rodrigo-riquelme-reche/20/159586    1
#                                                                     ..
# https://sofifa.com/player/202474/anibal-araujo-capela/20/159586      1
# https://sofifa.com/player/203398/derrick-williams/20/159586          1
# https://sofifa.com/player/203751/conor-townsend/20/159586            1
# https://sofifa.com/player/203875/jurgen-mattheij/20/159586           1
# https://sofifa.com/player/233449/ximing-pan/20/159586                1
# Name: player_url, Length: 18278, dtype: int64
# *************************
# short_name ['L. Messi' 'Cristiano Ronaldo' 'Neymar Jr' ... 'Xiao Mingjie'
#  'Wang Haijian' 'Pan Ximing']
# J. Rodríguez    11
# Paulinho         9
# J. García        8
# J. Williams      7
# J. Hernández     7
#                 ..
# Eguaras          1
# S. Mugoša        1
# Crislan          1
# L. Paganini      1
# Pan Ximing       1
# Name: short_name, Length: 17354, dtype: int64
# *************************
# long_name ['Lionel Andrés Messi Cuccittini' 'Cristiano Ronaldo dos Santos Aveiro'
#  'Neymar da Silva Santos Junior' ... '张威' '汪海健' '潘喜明']
# Liam Kelly           3
# Mathias Jørgensen    2
# Tommy Smith          2
# Luke McCormick       2
# Michael Smith        2
#                     ..
# Andrei Artean        1
# 김승규 金承奎              1
# Patrick Farkas       1
# Marcel Ritzmaier     1
# 潘喜明                  1
# Name: long_name, Length: 18218, dtype: int64
# *************************
# age [32 34 27 26 28 33 20 25 31 30 24 29 23 19 22 37 36 21 41 38 35 18 40 39
#  17 16 42]
# 22    1446
# 21    1375
# 23    1358
# 27    1324
# 25    1319
# 24    1296
# 26    1270
# 20    1247
# 28    1086
# 19    1011
# 29     999
# 30     883
# 31     807
# 18     640
# 32     597
# 33     475
# 35     310
# 34     301
# 17     229
# 36     131
# 37      81
# 38      42
# 39      20
# 40      13
# 16      12
# 41       4
# 42       2
# Name: age, dtype: int64
# *************************
# dob ['1987-06-24' '1985-02-05' '1992-02-05' ... '1999-12-14' '1997-11-16'
#  '2000-07-09']
# 1992-02-29    113
# 1984-02-29    111
# 1988-02-29    110
# 1997-01-01     15
# 2001-01-01     13
#              ...
# 1982-12-23      1
# 1984-06-22      1
# 1984-04-16      1
# 1982-01-08      1
# 2000-07-09      1
# Name: dob, Length: 6142, dtype: int64
# *************************
# height_cm [170 187 175 188 181 193 172 178 191 192 168 173 184 182 189 176 177 199
#  194 185 183 180 179 169 186 174 163 165 195 190 196 171 197 167 198 166
#  164 200 161 158 201 203 162 157 160 159 156 202 205]
# 180    1468
# 178    1213
# 185    1193
# 183    1160
# 175     990
# 188     904
# 182     833
# 184     820
# 186     774
# 177     722
# 181     704
# 187     682
# 176     669
# 179     641
# 190     585
# 173     567
# 174     483
# 191     464
# 170     455
# 189     439
# 172     412
# 193     316
# 192     290
# 171     262
# 168     195
# 194     173
# 169     149
# 196     139
# 195     136
# 167     102
# 165      68
# 166      60
# 197      51
# 198      35
# 163      29
# 164      21
# 199      14
# 162      12
# 201      11
# 200      10
# 203       6
# 161       5
# 202       4
# 158       3
# 160       3
# 159       3
# 157       1
# 156       1
# 205       1
# Name: height_cm, dtype: int64
# *************************
# weight_kg [ 72  83  68  87  74  70  85  92  66  71  73  89  91  82  86  80  76  75
#   84  69  96  67  77  78  64  81  61  94  59  60  90  79  97  65  95  93
#   63  62  88 100  98  58 101 103  56  99  57 102  55  52  54 104 107  53
#  110  50]
# 70     1455
# 75     1410
# 80     1060
# 78     1005
# 72      983
# 73      948
# 74      890
# 77      880
# 76      860
# 68      707
# 79      659
# 71      612
# 82      584
# 83      532
# 69      524
# 81      516
# 65      488
# 67      473
# 84      454
# 85      445
# 66      366
# 64      297
# 86      296
# 88      255
# 87      230
# 63      207
# 90      169
# 62      157
# 60      142
# 89      135
# 61       81
# 92       81
# 91       74
# 93       54
# 94       42
# 59       36
# 58       35
# 95       29
# 96       21
# 57       15
# 56       13
# 97       12
# 98       10
# 55        6
# 54        6
# 101       4
# 103       3
# 99        3
# 102       3
# 100       2
# 52        2
# 104       2
# 53        2
# 107       1
# 110       1
# 50        1
# Name: weight_kg, dtype: int64
# *************************
# nationality ['Argentina' 'Portugal' 'Brazil' 'Slovenia' 'Belgium' 'Germany'
#  'Netherlands' 'Croatia' 'Egypt' 'France' 'Senegal' 'England' 'Spain'
#  'Italy' 'Uruguay' 'Poland' 'Denmark' 'Gabon' 'Korea Republic'
#  'Costa Rica' 'Slovakia' 'Bosnia Herzegovina' 'Serbia' 'Scotland'
#  'Hungary' 'Switzerland' 'Greece' 'Austria' 'Morocco' 'Sweden' 'Wales'
#  'Colombia' 'Czech Republic' 'Chile' 'Algeria' 'Ivory Coast' 'Togo'
#  'Norway' 'Mexico' 'Iceland' 'Finland' 'Jamaica' 'Albania' 'Guinea'
#  'Cameroon' 'Ghana' 'Montenegro' 'Ukraine' 'Russia' 'DR Congo'
#  'Central African Rep.' 'Venezuela' 'Nigeria' 'Armenia' 'Israel' 'Ecuador'
#  'Paraguay' 'Australia' 'Turkey' 'Romania' 'Japan' 'Mali' 'United States'
#  'Kosovo' 'Dominican Republic' 'Tanzania' 'China PR' 'Northern Ireland'
#  'Republic of Ireland' 'Tunisia' 'Cape Verde' 'FYR Macedonia'
#  'Burkina Faso' 'Kenya' 'Angola' 'South Africa' 'Peru' 'Syria' 'Gambia'
#  'New Zealand' 'Equatorial Guinea' 'Zimbabwe' 'Georgia' 'Canada' 'Estonia'
#  'Benin' 'Bulgaria' 'Mozambique' 'Honduras' 'Guinea Bissau' 'Iran'
#  'Philippines' 'Cyprus' 'Madagascar' 'Uzbekistan' 'Moldova' 'Cuba'
#  'Sierra Leone' 'Curacao' 'Zambia' 'Congo' 'Bolivia' 'Comoros' 'Iraq'
#  'Chad' 'Lithuania' 'Saudi Arabia' 'Panama' 'Libya' 'Bahrain'
#  'St Kitts Nevis' 'New Caledonia' 'Luxembourg' 'Trinidad & Tobago'
#  'Thailand' 'United Arab Emirates' 'Eritrea' 'Korea DPR' 'El Salvador'
#  'Azerbaijan' 'Latvia' 'Montserrat' 'Puerto Rico' 'Bermuda'
#  'São Tomé & Príncipe' 'Antigua & Barbuda' 'Burundi' 'Kazakhstan'
#  'Liberia' 'Guyana' 'Haiti' 'Jordan' 'Faroe Islands' 'Mauritania'
#  'Namibia' 'Rwanda' 'Uganda' 'Hong Kong' 'Chinese Taipei' 'Belize'
#  'Palestine' 'Mauritius' 'Guam' 'Suriname' 'Lebanon' 'Guatemala' 'Sudan'
#  'Liechtenstein' 'Grenada' 'St Lucia' 'Afghanistan' 'Ethiopia' 'Barbados'
#  'India' 'Malta' 'Niger' 'Vietnam' 'Malawi' 'Gibraltar' 'Macau'
#  'South Sudan' 'Indonesia']
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64
# *************************
# club ['FC Barcelona' 'Juventus' 'Paris Saint-Germain' 'Atlético Madrid'
#  'Real Madrid' 'Manchester City' 'Liverpool' 'Napoli' 'Tottenham Hotspur'
#  'Manchester United' 'Chelsea' 'FC Bayern München' 'Inter'
#  'Borussia Dortmund' 'Arsenal' 'Valencia CF' 'Lazio' 'Milan' 'Sporting CP'
#  'Olympique Lyonnais' 'RB Leipzig' 'Ajax' 'LA Galaxy' 'Atalanta'
#  'RC Celta' 'Bayer 04 Leverkusen' 'Real Betis' 'FC Porto'
#  'SV Werder Bremen' 'West Ham United' 'Wolverhampton Wanderers'
#  'AS Saint-Étienne' 'Torino' 'Dalian YiFang FC' 'Borussia Mönchengladbach'
#  'Roma' 'Guangzhou Evergrande Taobao FC' 'SL Benfica'
#  'Medipol Başakşehir FK' 'Everton' 'VfL Wolfsburg' 'Crystal Palace'
#  'Getafe CF' 'Shanghai SIPG FC' 'Eintracht Frankfurt'
#  'Olympique de Marseille' 'Hertha BSC' 'RSC Anderlecht' 'Villarreal CF'
#  'Sampdoria' 'Leicester City' 'AS Monaco' 'Jiangsu Suning FC'
#  'Los Angeles FC' 'Cagliari' 'Sevilla FC' 'Fenerbahçe SK' 'Real Sociedad'
#  'TSG 1899 Hoffenheim' 'Atlético Mineiro' 'Grêmio' 'PSV'
#  'Athletic Club de Bilbao' 'Deportivo Alavés' 'Boca Juniors'
#  'Lokomotiv Moscow' 'Al Nassr' 'Brescia' 'Shakhtar Donetsk'
#  'Shanghai Greenland Shenhua FC' 'PFC CSKA Moscow'
#  'Beijing Sinobo Guoan FC' 'Levante UD' 'Cruzeiro' 'Uruguay'
#  'Montpellier HSC' 'Atlanta United' 'Watford' '1. FC Köln' 'Bournemouth'
#  'Beşiktaş JK' 'Real Valladolid CF' 'Racing Club' 'Al Hilal'
#  'Guangzhou R&F FC' 'Sassuolo' 'FC Girondins de Bordeaux' 'LOSC Lille'
#  'Galatasaray SK' 'Chicago Fire' 'Fluminense' 'Ecuador' 'RCD Espanyol'
#  'Dinamo Zagreb' 'FC Nantes' 'River Plate' 'OGC Nice' 'Newcastle United'
#  'Brighton & Hove Albion' 'Club Brugge KV' 'FC Schalke 04' 'SD Eibar'
#  'DC United' 'Orlando City SC' 'Hebei China Fortune FC' 'Tigres U.A.N.L.'
#  'Aston Villa' 'Montreal Impact' 'Olympiacos CFP' 'Norwich City'
#  'Feyenoord' 'Toronto FC' 'KRC Genk' 'Fiorentina' 'Spartak Moscow'
#  'Dynamo Kyiv' 'SK Slavia Praha' 'Southampton' 'Burnley' 'SC Braga'
#  'Russia' 'RC Strasbourg Alsace' 'Wuhan Zall' 'Vissel Kobe'
#  'Portland Timbers' 'Genoa' 'Beijing Renhe FC' 'Toulouse Football Club'
#  'Girona FC' 'Real Zaragoza' 'CD Leganés' 'Shenzhen FC' 'Internacional'
#  'CSA - AL' 'Santos' '1. FSV Mainz 05' 'Stoke City' 'Udinese' 'Colombia'
#  'Angers SCO' 'FC Augsburg' 'Netherlands' 'Fulham' 'FC København'
#  'KAA Gent' 'SC Freiburg' 'Stade Rennais FC' 'Club América' 'Trabzonspor'
#  'BSC Young Boys' 'Helsingborgs IF' 'Kaizer Chiefs' 'Parma' 'Mexico'
#  'Royal Antwerp FC' 'Tianjin TEDA FC' 'Hannover 96' 'Tianjin Quanjian FC'
#  'Al Ahli' 'Bologna' 'VfB Stuttgart' 'Seattle Sounders FC' 'Godoy Cruz'
#  'Sparta Praha' 'Independiente Medellín' 'Sivasspor' 'Independiente'
#  'Nîmes Olympique' 'Club Tijuana' 'SPAL' 'Monterrey' 'CD Tondela'
#  'Fortuna Düsseldorf' 'Vitória Guimarães' 'AZ Alkmaar'
#  'Atlético de San Luis' 'PAOK' 'Nagoya Grampus' 'Club Atlético Banfield'
#  'Shandong Luneng TaiShan FC' 'New York Red Bulls' 'FC Red Bull Salzburg'
#  'Sweden' 'Amiens SC' 'Hellas Verona' 'Cruz Azul' 'Gençlerbirliği SK'
#  '1. FC Union Berlin' 'Standard de Liège'
#  'Chongqing Dangdai Lifan FC SWM Team' 'New England Revolution'
#  'Club Atlético Colón' 'Celtic' 'Club Atlas' 'Botafogo'
#  'En Avant de Guingamp' 'West Bromwich Albion' 'Pachuca' 'AEK Athens'
#  'Portimonense SC' 'Real Salt Lake' 'FC Utrecht' 'Sheffield United'
#  "Newell's Old Boys" 'Club Atlético Talleres' 'Philadelphia Union'
#  'Rosenborg BK' 'FC Basel 1893' 'Brentford' 'Club León'
#  'Unión de Santa Fe' 'Deportivo de La Coruña' 'Rangers FC' 'Turkey'
#  'Atiker Konyaspor' 'Granada CF' 'Perth Glory' 'Club Atlético Lanús'
#  'Hamburger SV' 'Al Ittihad' 'Santos Laguna' 'Western United FC'
#  'Columbus Crew SC' 'Deportivo Toluca' 'Cardiff City' 'CA Osasuna'
#  'Swansea City' 'Melbourne Victory' 'Leeds United' 'Göztepe SK' 'Hungary'
#  'New York City FC' 'Bulgaria' 'Kayserispor' 'Minnesota United FC'
#  'Guadalajara' 'FC Groningen' 'Paraguay' 'Junior FC' 'Al Taawoun'
#  'Huddersfield Town' 'Ettifaq FC' 'Stade de Reims' 'Rayo Vallecano'
#  'San Lorenzo de Almagro' 'Bahia' 'Atlético Paranaense' 'Goiás' 'Avaí FC'
#  'Fortaleza' 'Kawasaki Frontale' 'Vélez Sarsfield' 'Hull City'
#  'Houston Dynamo' 'Birmingham City' 'Al Wehda' 'Nottingham Forest'
#  'CD Tenerife' 'Aalborg BK' 'Preston North End' 'Bristol City' 'Lecce'
#  'Gimnasia y Esgrima La Plata' 'CD Aves' 'Viktoria Plzeň' '1. FC Nürnberg'
#  'Slovenia' 'FC Metz' 'FC Midtjylland' 'Molde FK' 'Colo-Colo'
#  'RCD Mallorca' 'FC Sion' 'Wisła Kraków' 'Denizlispor' 'Middlesbrough'
#  'Universidad Católica' 'Alanyaspor' 'Moreirense FC' "Côte d'Ivoire"
#  'Stade Brestois 29' 'Chievo Verona' 'Boavista FC' 'MKE Ankaragücü'
#  'Sydney FC' 'Al Ain FC' 'Yeni Malatyaspor' 'Urawa Red Diamonds'
#  'Querétaro' 'Sporting Kansas City' 'Málaga CF' '1. FC Heidenheim 1846'
#  'Atlético Tucumán' 'Gazişehir Gaziantep F.K.' 'Clube Sport Marítimo'
#  'Chapecoense' 'Atlético Nacional' 'Vitesse' 'Australia' 'Henan Jianye FC'
#  'Panathinaikos FC' 'Blackburn Rovers' 'Santa Clara' 'Cameroon'
#  'Puebla FC' 'U.N.A.M.' 'SD Huesca' 'Estudiantes de La Plata' 'Austria'
#  'KAS Eupen' 'LASK Linz' 'Sporting de Charleroi' 'Daegu FC'
#  'Real Sporting de Gijón' 'Derby County' 'Rio Ave FC' 'South Africa'
#  'Famalicão' 'Neuchâtel Xamax' 'Benevento' 'Cádiz CF' 'AIK'
#  'Sheffield Wednesday' 'Empoli' 'Colorado Rapids' 'Os Belenenses'
#  'Unión Magdalena' 'Real Oviedo' 'Peru' 'Antalyaspor' 'Dijon FCO'
#  'SV Sandhausen' 'Rosario Central' 'Reading' 'DSC Arminia Bielefeld'
#  'Malmö FF' 'Jeonbuk Hyundai Motors' 'Frosinone' 'FC Tokyo' 'Canada'
#  'Çaykur Rizespor' 'FCSB (Steaua)' 'Defensa y Justicia' 'Monarcas Morelia'
#  'Club Atlético Huracán' 'Ceará Sporting Club' 'Argentinos Juniors'
#  'Al Shabab' 'Legia Warszawa' 'Shimizu S-Pulse' 'Millonarios FC'
#  'Lechia Gdańsk' 'Brøndby IF' 'Albacete BP' 'FC Lorient'
#  'Universitatea Craiova' 'Deportivo Cali' 'SK Rapid Wien'
#  'Kashima Antlers' 'Poland' 'Elche CF' 'Club Atlético Aldosivi'
#  'Deportes Tolima' 'Cúcuta Deportivo' 'Club Necaxa' 'Piast Gliwice'
#  'Pescara' 'Kasimpaşa SK' 'Egypt' 'Holstein Kiel' 'Livorno'
#  'Coquimbo Unido' 'UD Las Palmas' 'Górnik Zabrze' 'FC Twente' 'Paris FC'
#  'Racing Club de Lens' 'VfL Bochum 1848' 'Sunderland' 'Aberdeen'
#  'Heart of Midlothian' 'Romania' 'Crotone' 'Iceland' 'CFR Cluj'
#  'FK Austria Wien' 'UD Almería' 'SK Brann' 'BK Häcken' 'Al Fateh'
#  'CD Everton de Viña del Mar' 'FC St. Pauli' 'Gamba Osaka'
#  'Yokohama F. Marinos' 'Djurgårdens IF' 'FC Dallas' 'Sagan Tosu'
#  'Al Fayha' 'Chile' 'Once Caldas' 'Atlético Bucaramanga' 'FC Cincinnati'
#  'San Jose Earthquakes' 'América de Cali' 'Perugia' 'La Equidad'
#  'SV Darmstadt 98' 'FC Zürich' 'SC Paderborn 07' 'SV Zulte-Waregem'
#  'IFK Norrköping' 'FC Viitorul' 'Pordenone' 'AD Alcorcón'
#  'Sint-Truidense VV' 'KV Kortrijk' 'Royal Excel Mouscron' 'FC Lugano'
#  'Hokkaido Consadole Sapporo' 'Spezia' 'FC Paços de Ferreira'
#  'Servette FC' 'US Salernitana 1919' 'Lech Poznań' 'ESTAC Troyes'
#  'Fortuna Sittard' 'KV Oostende' 'VVV-Venlo' 'KSV Cercle Brugge'
#  'FC Seoul' 'Cerezo Osaka' 'Stade Malherbe Caen' 'Universidad de Chile'
#  'Kalmar FF' 'KV Mechelen' 'Deportes Iquique' 'US Cremonese' 'Bolivia'
#  'Valenciennes FC' 'Ulsan Hyundai FC' 'Vegalta Sendai' 'ADO Den Haag'
#  'CD Palestino' 'Cittadella' 'Vitória de Setúbal' 'FC Nordsjælland'
#  'Charlton Athletic' 'Al Raed' 'Jagiellonia Białystok' 'Odense Boldklub'
#  'FC Thun' 'SG Dynamo Dresden' 'Hammarby IF' 'Central Córdoba'
#  'Queens Park Rangers' ' SSV Jahn Regensburg'
#  'Tiburones Rojos de Veracruz' 'Patronato' 'Virtus Entella'
#  'SK Sturm Graz' 'Kilmarnock' 'Extremadura UD' 'Willem II'
#  'Gil Vicente FC' 'Randers FC' 'Ascoli' 'Vancouver Whitecaps FC'
#  'Millwall' 'Pohang Steelers' 'Suwon Samsung Bluewings' 'Heracles Almelo'
#  'Al Hazem' 'FC Juárez' 'SC Heerenveen' 'Dinamo Bucureşti' 'Gyeongnam FC'
#  'KFC Uerdingen 05' 'PEC Zwolle' 'Al Faisaly' 'Arsenal de Sarandí'
#  'FC Ingolstadt 04' 'Wolfsberger AC' 'Wigan Athletic' 'Júbilo Iwata'
#  'CD Lugo' 'SpVgg Greuther Fürth' 'FC Emmen' 'Cosenza' 'AJ Auxerre'
#  'Cracovia' 'FC Erzgebirge Aue' 'Grenoble Foot 38' 'Korona Kielce'
#  'Alianza Petrolera' 'CD Universidad de Concepción' 'Melbourne City FC'
#  'CD Antofagasta' 'Independiente Santa Fe' 'Sanfrecce Hiroshima'
#  'Damac FC' 'Chamois Niortais Football Club' 'Atlético Huila'
#  'CD Numancia' 'Luton Town' 'Unión La Calera' 'Le Havre AC'
#  'AS Nancy Lorraine' 'Audax Italiano' 'Hibernian' 'Barnsley'
#  'Pogoń Szczecin' 'Sarpsborg 08 FF' 'Kristiansund BK' 'FC Luzern'
#  'Unión Española' 'IFK Göteborg' 'Envigado FC' 'Jeju United FC'
#  'Patriotas Boyacá FC' 'Peterborough United' 'Deportivo Pasto' 'Wales'
#  'Clermont Foot 63' 'Northern Ireland' 'Astra Giurgiu' 'Racing Santander'
#  'Pisa' 'Newcastle Jets' 'Castellammare di Stabia' 'Rionegro Águilas'
#  'Vålerenga Fotball' "CD O'Higgins" 'AC Ajaccio' 'CF Fuenlabrada'
#  'VfL Osnabrück' 'Arka Gdynia' 'FC Sochaux-Montbéliard'
#  'SpVgg Unterhaching' 'Central Coast Mariners' 'SV Wehen Wiesbaden'
#  'Fleetwood Town' 'Venezia FC' 'Karlsruher SC' 'Wisła Płock' 'Gangwon FC'
#  'IF Elfsborg' 'Sangju Sangmu FC' 'Zagłębie Lubin' 'Abha Club'
#  'Jaguares de Córdoba' 'FC Botoşani' 'Motherwell' 'FC St. Gallen'
#  'Bayern München II' 'CD Mirandés' 'St. Johnstone FC' 'Lillestrøm SK'
#  'Odds BK' 'SD Ponferradina' 'Doncaster Rovers' 'Örebro SK'
#  'Shamrock Rovers' 'FSV Zwickau' '1. FC Kaiserslautern' 'Portsmouth'
#  'Waasland-Beveren' 'Ipswich Town' 'Dundalk' 'CD Huachipato' 'Le Mans FC'
#  'Strømsgodset IF' 'Sepsi OSK' 'Sparta Rotterdam'
#  'FC Admira Wacker Mödling' 'SønderjyskE' 'Hallescher FC' 'SKN St. Pölten'
#  'MSV Duisburg' 'La Berrichonne de Châteauroux' 'FC Hansa Rostock'
#  'Incheon United FC' 'Shonan Bellmare' 'Orlando Pirates' 'FK Bodø/Glimt'
#  'Lincoln City' 'Brisbane Roar' 'Eintracht Braunschweig' 'Curicó Unido'
#  'Falkenbergs FF' 'Venezuela' '1. FC Magdeburg' 'CD Cobresal' 'Aarhus GF'
#  'Salford City' 'HJK Helsinki' 'Oxford United' 'Hobro IK' 'Esbjerg fB'
#  'Bolton Wanderers' 'SV Mattersburg' 'Rotherham United' 'SCR Altach'
#  'Gaz Metan Mediaş' 'Tromsø IL' 'WSG Tirol' 'IK Sirius' 'Shrewsbury'
#  'Oldham Athletic' 'Southend United' 'Blackpool' 'Coventry City'
#  'Adelaide United' 'Ranheim Fotball' 'SG Sonnenhof Großaspach'
#  'Matsumoto Yamaga' 'Burton Albion' 'FC Hermannstadt' 'TSV 1860 München'
#  'LKS Lodz' 'FC Würzburger Kickers' 'TSV Hartberg' 'Politehnica Iaşi'
#  'Wellington Phoenix' 'Milton Keynes Dons' 'Stabæk Fotball'
#  'Wycombe Wanderers' 'SV Waldhof Mannheim' 'AC Horsens'
#  'Scunthorpe United' 'RKC Waalwijk' 'Oita Trinita' 'St. Mirren'
#  'Bristol Rovers' 'Rodez Aveyron Football' 'SV Meppen' 'Viking FK'
#  'Östersunds FK' 'FK Haugesund' 'Rochdale' 'Colchester United' 'Trapani'
#  'Stevenage' 'Bradford City' 'Livingston FC' 'FC Chambly Oise'
#  'Mansfield Town' 'SC Preußen Münster' 'FC Voluntari' 'Accrington Stanley'
#  'Al Adalah' 'Lyngby BK' 'FC Carl Zeiss Jena' 'Viktoria Köln'
#  'Tranmere Rovers' 'Silkeborg IF' 'Gillingham' 'Plymouth Argyle'
#  'Chemnitzer FC' 'Mjøndalen IF' 'Walsall' 'Northampton Town'
#  'Hamilton Academical FC' 'Grimsby Town' 'Exeter City' 'Swindon Town'
#  'Raków Częstochowa' 'Chindia Târgovişte' 'US Orléans Loiret Football'
#  'Forest Green Rovers' 'AFC Wimbledon' 'Carlisle United' 'Morecambe'
#  'Port Vale' 'Cheltenham Town' 'Academica Clinceni' 'Crawley Town'
#  'Ross County FC' 'AFC Eskilstuna' 'Macclesfield Town' 'Cork City'
#  'Newport County' 'Crewe Alexandra' 'Leyton Orient' 'Cambridge United'
#  "St. Patrick's Athletic" 'Bohemian FC' 'India' 'Finland' 'Waterford FC'
#  'Derry City' 'Bury' 'New Zealand' 'GIF Sundsvall' 'Sligo Rovers'
#  'Finn Harps' 'Seongnam FC' 'UCD AFC' 'Śląsk Wrocław']
# FC Barcelona                  33
# Real Valladolid CF            33
# VfL Wolfsburg                 33
# Crystal Palace                33
# Eintracht Frankfurt           33
#                               ..
# US Orléans Loiret Football     1
# Canada                         1
# Mexico                         1
# Turkey                         1
# Śląsk Wrocław                  1
# Name: club, Length: 698, dtype: int64
# *************************
# overall [94 93 92 91 90 89 88 87 86 85 84 83 82 81 80 79 78 77 76 75 74 73 72 71
#  70 69 68 67 66 65 64 63 62 61 60 59 58 57 56 55 54 53 52 51 50 49 48]
# 66    1141
# 64    1138
# 65    1124
# 68    1068
# 67    1065
# 69     964
# 63     946
# 70     902
# 62     873
# 72     753
# 71     715
# 60     701
# 61     649
# 73     638
# 59     545
# 74     529
# 75     506
# 58     485
# 76     361
# 56     360
# 57     360
# 55     274
# 77     262
# 78     239
# 54     232
# 53     197
# 79     185
# 52     169
# 80     157
# 51     117
# 50     103
# 82      92
# 81      82
# 83      80
# 49      66
# 84      49
# 48      43
# 85      35
# 86      18
# 88      17
# 87      15
# 89      13
# 90       4
# 91       3
# 93       1
# 92       1
# 94       1
# Name: overall, dtype: int64
# *************************
# potential [94 93 92 91 90 95 89 88 87 86 85 84 83 82 81 80 79 78 77 76 75 74 73 72
#  71 70 69 68 67 66 65 64 63 62 61 60 59 58 57 56 55 54 53 52 51 50 49]
# 70    1226
# 68    1195
# 73    1140
# 72    1131
# 71    1118
# 69    1111
# 74    1022
# 67     987
# 75     972
# 66     882
# 76     835
# 65     781
# 64     657
# 77     650
# 78     635
# 79     497
# 63     459
# 80     418
# 62     351
# 81     306
# 82     291
# 83     255
# 61     228
# 84     214
# 60     172
# 85     138
# 59     122
# 86     116
# 87      70
# 58      68
# 88      45
# 57      43
# 89      37
# 56      26
# 55      17
# 90      16
# 91       9
# 92       7
# 54       7
# 53       6
# 93       5
# 51       4
# 52       3
# 50       2
# 49       2
# 95       1
# 94       1
# Name: potential, dtype: int64
# *************************
# value_eur [ 95500000  58500000 105500000  77500000  90000000  67500000  78000000
#   45000000  80500000  93500000  83000000  58000000  56000000  66000000
#   24500000  60000000  31500000  53000000  64500000  55000000  69000000
#   76500000  72500000  54500000  73000000  68000000  48000000  38000000
#   26000000  32000000  36000000  47000000  28000000  57000000  62000000
#   56500000  64000000  53500000  19500000  18500000  32500000  40000000
#   41000000  50000000  30500000  52000000  61000000  51500000  37500000
#   51000000  42500000  39000000  28500000  46500000  43500000  44500000
#   46000000  41500000  50500000  49500000  49000000  33500000  31000000
#   14000000  34000000  34500000  25000000  33000000  40500000  36500000
#   39500000   6500000  23500000  19000000  26500000  23000000  20500000
#   29500000  25500000  21000000  24000000  29000000  35000000  35500000
#   30000000  22000000  27500000  27000000  21500000  20000000   2600000
#   11500000  12000000   9500000  15500000  16500000  22500000  17000000
#   18000000   3700000   7000000   8000000  13500000  11000000  17500000
#   10500000  10000000         0  16000000   5500000  15000000   8500000
#    6000000  13000000  14500000  12500000   5000000   4000000   4700000
#    1500000   2500000   3000000   9000000   7500000   4500000   3400000
#    3800000   3600000   2100000   4800000   4900000   2900000   4300000
#    2800000   2400000   3300000   4100000   2700000   4200000   1300000
#    1600000   1700000    775000   3200000   3500000   3900000   2200000
#     675000   2000000   1800000   2300000   3100000   4400000   4600000
#    1100000    950000   1900000   1000000    400000    800000   1400000
#    1200000    725000    625000    525000    850000    975000    325000
#     875000    575000    240000    475000    425000    500000    900000
#     650000    750000    825000    375000    180000    550000    300000
#     350000    600000    925000    260000    450000    110000    190000
#     230000    700000    210000    280000    160000    120000    150000
#      90000    250000    270000    130000     80000    220000     70000
#     140000    200000    290000    170000     50000    100000     40000
#      60000     30000     20000     10000]
# 1100000     491
# 325000      384
# 450000      358
# 1200000     346
# 425000      339
#            ...
# 56500000      1
# 62000000      1
# 68000000      1
# 73000000      1
# 95500000      1
# Name: value_eur, Length: 214, dtype: int64
# *************************
# wage_eur [565000 405000 290000 125000 470000 370000 250000 200000 340000 240000
#  155000 150000 220000 205000 235000 215000 300000 355000 185000 255000
#  285000 110000 265000 195000 135000 330000 170000 210000 130000 180000
#  140000 120000  89000 245000 160000 175000  69000 105000 165000  76000
#   34000 115000  73000  77000  24000  88000  92000  39000  15000 145000
#   49000 225000  61000  70000  94000  40000  91000  78000  23000  37000
#   16000  41000  54000  26000  71000  75000  96000  43000  44000  36000
#   67000  74000  46000  38000  97000  18000  64000  93000 100000  50000
#   80000  35000  29000  42000  60000  58000  11000  33000  31000  45000
#   82000  32000  17000  48000  51000  86000  21000  65000  63000  95000
#   22000  90000  59000  47000  68000  99000  56000  27000  98000  85000
#    1000  52000  20000  87000  28000      0  30000  14000  57000  79000
#   19000  66000  62000  13000  25000  84000  12000  53000  81000  55000
#   72000  10000  83000   4000   6000   9000   7000   8000   3000   5000
#    2000]
# 1000      4976
# 2000      2967
# 3000      1825
# 4000      1303
# 5000       891
#           ...
# 255000       1
# 265000       1
# 330000       1
# 93000        1
# 565000       1
# Name: wage_eur, Length: 141, dtype: int64
# *************************
# player_positions ['RW, CF, ST' 'ST, LW' 'LW, CAM' 'GK' 'LW, CF' 'CAM, CM' 'CB' 'CM'
#  'RW, ST' 'ST, RW' 'ST' 'CDM, CM' 'CF, ST, LW' 'CAM, RW' 'CM, CDM'
#  'RW, LW' 'CAM, LM, ST' 'ST, LM' 'LW, LM' 'CB, LB' 'RW, CAM, CM' 'CDM'
#  'CF, LM' 'CF, ST' 'LB' 'CM, CAM, CDM' 'CF, LW, ST' 'LW' 'CB, CDM'
#  'RB, CM, CDM' 'CAM, CM, LW' 'CF, ST, CAM' 'LW, CM' 'CAM, RM, RW'
#  'CM, CAM' 'CM, LM, RM' 'LB, CB' 'RB' 'CAM, CF, ST' 'RW, LW, ST' 'LB, LM'
#  'RM, LM, CM' 'CAM, CM, RM' 'RM, LM' 'CAM, RM' 'CF, LW, CAM' 'CAM, LM, RM'
#  'LM, RM, LW' 'RM, LM, LW' 'CAM' 'CAM, CM, CF' 'LM' 'CDM, CB' 'RB, CB'
#  'RM, RW' 'LM, RW, LW' 'RM, CM' 'CAM, LW, ST' 'RW, RM' 'CM, CDM, CAM'
#  'CM, CAM, CF' 'LW, ST, LM' 'LM, ST' 'RM, RW, ST' 'LM, CAM, RM' 'LW, RW'
#  'CF, LM, LW' 'RM, CAM' 'CF, RM, LM' 'RW, LW, CAM' 'CDM, CM, CAM'
#  'CDM, CB, LB' 'ST, CAM, LW' 'ST, CF' 'RW, CAM' 'LW, LM, RW' 'RW, CAM, LW'
#  'RM, ST' 'CM, CDM, RM' 'RW, CF' 'RB, RM' 'CAM, LW' 'CF, CAM, CM'
#  'RB, RM, CM' 'LWB, LM, LB' 'ST, RW, LW' 'CB, LB, RB' 'RM, LM, CF'
#  'CAM, LM' 'LM, LWB' 'LM, RM' 'RM, RB' 'CM, CDM, LM' 'CM, LW' 'RWB, RM'
#  'RW' 'CB, RB' 'CM, LM, CDM' 'CAM, CM, LM' 'LW, RW, CAM' 'CM, LM'
#  'CAM, CM, RW' 'LM, LB, CM' 'CM, LB' 'CF, ST, RM' 'LB, LWB' 'RM, CAM, RW'
#  'RB, RW, LW' 'LW, LB' 'CAM, LM, LW' 'CF, LW' 'RM, LM, CAM' 'RB, RWB'
#  'LM, LW' 'RM, ST, LM' 'CM, RM' 'CF, RW, LW' 'CAM, CF' 'ST, LW, CAM' 'RM'
#  'RWB, RB, RM' 'LW, CAM, CM' 'LM, ST, RM' 'CM, RB, RM' 'LW, CF, ST'
#  'LM, CAM' 'RB, CDM, CM' 'RM, RW, CAM' 'CF' 'LM, RW' 'RM, RW, LM' 'ST, RM'
#  'CAM, LM, CM' 'CDM, CM, LM' 'RW, ST, LW' 'LB, RB' 'RB, LB' 'LW, CF, RW'
#  'LB, LM, LWB' 'RM, CAM, CM' 'LM, LW, RM' 'CDM, CM, CB' 'ST, RW, LM'
#  'RM, LM, ST' 'LM, CF' 'CDM, CB, CM' 'LWB, LB' 'RWB, RM, RB' 'ST, LM, LW'
#  'LM, LB' 'RWB' 'ST, RW, RM' 'ST, CAM' 'CAM, CDM' 'CAM, ST' 'CF, CM'
#  'CF, RW' 'CM, LW, RW' 'RM, CAM, LM' 'RB, RM, CB' 'LB, CDM' 'CAM, RM, CM'
#  'CM, CB' 'CB, RB, LB' 'LM, RM, CAM' 'CM, LM, CAM' 'CF, CM, LW'
#  'RW, ST, RM' 'CF, RW, RM' 'CAM, RM, LM' 'LM, LW, CM' 'ST, CF, CAM'
#  'LM, LW, ST' 'RM, RWB' 'CF, LW, RW' 'CDM, CM, RB' 'RB, RW' 'CM, CAM, RW'
#  'RM, ST, RW' 'CAM, RM, CF' 'CM, RM, CAM' 'LW, CAM, LM' 'RB, RWB, RM'
#  'RB, CM' 'CM, RB' 'CM, CAM, RM' 'LM, LWB, LW' 'LM, LW, CF' 'LB, LWB, LM'
#  'LM, RM, CM' 'RM, RWB, LWB' 'LM, LW, CAM' 'LW, CAM, RM' 'CAM, CM, CDM'
#  'CM, CAM, LM' 'RB, LB, RM' 'LB, CM' 'CAM, RW, LW' 'RM, LM, RW'
#  'CM, CDM, CF' 'CM, CDM, RB' 'LM, CAM, CM' 'ST, CAM, CF' 'RM, CM, RB'
#  'CM, RW, CAM' 'LW, RW, ST' 'CDM, RWB' 'CAM, RW, RM' 'CM, CB, CAM'
#  'LM, RM, RB' 'RM, CF, RW' 'LW, RM, LM' 'CM, RM, CDM' 'ST, CF, RW'
#  'LM, LB, LWB' 'LM, RM, ST' 'CAM, RW, CM' 'LW, LM, CF' 'RWB, RB'
#  'CDM, CAM, LM' 'RW, LW, RM' 'CAM, ST, CDM' 'LM, CM' 'CM, ST' 'LM, RB'
#  'LB, RM' 'RM, CM, LM' 'LW, RM' 'LW, ST, RW' 'CM, LWB, LM' 'CF, CAM, ST'
#  'RM, LW' 'LW, RW, LM' 'CF, CAM' 'RW, LM, RM' 'RW, RM, CAM' 'LB, LM, CAM'
#  'ST, RM, CAM' 'CM, CDM, RWB' 'LM, LW, LB' 'ST, CAM, LM' 'RW, CM, RM'
#  'LM, RW, CF' 'CF, RW, ST' 'CDM, CAM, CM' 'RM, CM, RW' 'LM, CF, RM'
#  'CAM, LM, RW' 'CAM, ST, LM' 'LB, LWB, RB' 'LWB, LB, LM' 'RB, CB, RM'
#  'RW, CF, LW' 'LWB, LB, RB' 'LM, CM, CAM' 'CAM, CDM, CM' 'LW, ST'
#  'RB, CDM' 'CAM, ST, RW' 'CM, CDM, CB' 'CB, CDM, RB' 'RM, CF, LM'
#  'LWB, RM' 'ST, RM, LM' 'CAM, LW, CM' 'LM, CF, CM' 'RW, RM, RB'
#  'RB, RM, RWB' 'ST, LM, CAM' 'LM, ST, CAM' 'ST, LW, RW' 'RM, LM, LB'
#  'CM, LWB' 'CB, CDM, LB' 'CAM, LW, RW' 'LM, CAM, ST' 'RW, RWB'
#  'RM, RWB, RB' 'LM, CAM, LWB' 'LW, RW, RM' 'RWB, RB, LWB' 'CAM, ST, RM'
#  'RW, RM, CF' 'RW, RM, LW' 'RW, CAM, ST' 'RB, RM, LM' 'CM, CDM, LB'
#  'CDM, LB, CM' 'LM, CM, LB' 'LB, RB, RM' 'LW, CM, CAM' 'LB, RB, CB'
#  'CAM, ST, LW' 'LWB, LB, CB' 'LWB, LM' 'LWB' 'CDM, CB, RB' 'CM, LM, LB'
#  'RW, LB' 'RB, RM, LB' 'RW, RM, ST' 'CM, CAM, ST' 'CAM, CF, RW'
#  'CAM, RM, RB' 'ST, LM, RM' 'ST, RM, LW' 'CDM, CM, RM' 'RM, RW, CM'
#  'ST, CM, RB' 'RM, RW, LW' 'CB, RB, RM' 'CAM, RM, ST' 'RB, CM, CB'
#  'RW, LW, CM' 'RM, RWB, CAM' 'RW, RM, CM' 'RM, RB, RWB' 'RB, LW, LB'
#  'LB, CB, LWB' 'ST, CAM, CM' 'LM, RWB' 'RB, LB, CDM' 'CB, LWB'
#  'CM, RWB, RM' 'RM, CF' 'LB, CB, LM' 'LWB, RWB' 'RB, LB, RWB' 'RW, LW, LM'
#  'LM, CM, LWB' 'LM, ST, LW' 'RM, CAM, ST' 'RW, CAM, RM' 'LW, CAM, RW'
#  'LW, RW, CM' 'CAM, ST, CF' 'LB, CAM, LM' 'LB, CB, CDM' 'LM, RM, LB'
#  'LM, RM, CF' 'LB, LW' 'LM, LB, LW' 'ST, CAM, RM' 'LW, ST, CAM'
#  'ST, CAM, RW' 'ST, LW, LM' 'CAM, LM, CF' 'CAM, CF, CM' 'LM, RW, CAM'
#  'LB, RM, LM' 'CF, CAM, LM' 'CAM, RW, CF' 'CB, LB, CDM' 'CB, CDM, CM'
#  'CB, CM, CDM' 'RM, LM, RWB' 'RW, RM, LM' 'ST, LM, RB' 'RB, RM, RW'
#  'CB, RWB, RB' 'RB, CB, ST' 'CDM, CM, LB' 'RW, ST, CF' 'ST, RWB'
#  'LB, LWB, CDM' 'RB, RWB, LB' 'RM, CF, CAM' 'RB, LB, CB' 'RM, LW, RW'
#  'CDM, LB' 'CDM, RB, RM' 'CDM, RB' 'LB, CM, LM' 'RM, ST, CAM'
#  'CM, CDM, LW' 'CDM, RM' 'RM, RB, LB' 'LM, LWB, LB' 'CM, RW' 'CM, RM, RB'
#  'CM, LM, RB' 'RM, CAM, CF' 'CAM, CM, ST' 'CM, CF, CAM' 'RM, RB, CM'
#  'LW, LM, LB' 'RWB, RB, LB' 'RM, LM, CDM' 'LB, LM, RM' 'CM, CF'
#  'RB, CB, RWB' 'LW, LM, ST' 'CAM, RB' 'ST, CF, LW' 'LM, LB, CAM'
#  'CF, CM, CAM' 'CB, CDM, CAM' 'LM, CAM, LW' 'RM, LM, RB' 'RWB, LWB'
#  'RW, CM' 'CB, CM, RB' 'LB, RB, LW' 'RB, CDM, LB' 'CM, RW, LW'
#  'RWB, RB, CB' 'CF, RW, CAM' 'RB, CB, LB' 'CAM, LW, CF' 'CB, RB, CAM'
#  'LM, LW, RW' 'LB, CB, RB' 'ST, RW, CF' 'CDM, LM, CM' 'ST, LM, CF'
#  'LW, LM, CAM' 'LW, RM, CM' 'RB, CM, RWB' 'ST, CF, LM' 'CDM, CAM'
#  'LM, CDM' 'LB, LM, CB' 'CAM, CF, RM' 'RM, CM, CAM' 'CAM, CF, LW'
#  'LM, CM, ST' 'LM, RM, RW' 'CB, CM' 'LW, LM, RM' 'CB, LB, LWB'
#  'RM, RB, LW' 'LB, LM, CM' 'LM, RM, LWB' 'RB, LM, RM' 'CF, LM, CAM'
#  'LB, LWB, CB' 'RB, CM, RM' 'CM, LB, CDM' 'CAM, CF, LM' 'LW, CAM, CF'
#  'CDM, RB, CB' 'LW, LB, RW' 'LM, CM, RW' 'LM, RB, RWB' 'ST, CM'
#  'RM, CM, RWB' 'LM, ST, LB' 'RB, CB, CM' 'RW, LW, CF' 'CDM, RB, CM'
#  'RM, LM, LWB' 'LM, RW, RM' 'RB, LM' 'CB, LB, LM' 'RB, LB, LWB'
#  'RB, RWB, CB' 'LB, CM, LW' 'CM, RB, CDM' 'RM, LW, LM' 'CAM, ST, CM'
#  'LB, CDM, CM' 'LWB, LM, RWB' 'CDM, LWB, CM' 'LM, LWB, CM' 'CAM, CDM, CB'
#  'RM, LB' 'CDM, RB, LB' 'ST, RM, RW' 'RB, LB, LM' 'LB, CDM, LWB'
#  'LB, LM, RB' 'CDM, RM, CM' 'RWB, CB' 'CF, CM, LB' 'CM, CAM, LB'
#  'CDM, LWB' 'RW, CAM, CF' 'RM, RWB, LM' 'ST, LW, RM' 'RB, RM, CDM'
#  'RB, CB, CDM' 'CF, RM, ST' 'CM, ST, CF' 'LM, CAM, CDM' 'LW, CM, LB'
#  'LB, LM, LW' 'CM, LM, ST' 'CF, RM' 'RB, LB, RW' 'LM, CM, LW' 'LW, RW, CF'
#  'CDM, LM' 'CM, CB, CDM' 'LB, RB, LM' 'RM, LW, CAM' 'CB, LB, CM'
#  'CM, LW, LWB' 'RM, RWB, ST' 'ST, RW, CAM' 'ST, RB, RM' 'LB, RW, CM'
#  'CF, CAM, RW' 'RM, RW, RB' 'RB, CDM, CB' 'RB, RWB, CDM' 'LM, LB, RM'
#  'LM, CF, ST' 'CF, ST, LM' 'LB, RB, LWB' 'RM, ST, RB' 'CDM, CAM, RM'
#  'RB, CDM, RM' 'ST, LW, CM' 'CB, RB, CDM' 'LWB, CM' 'ST, RWB, LM'
#  'RM, CM, ST' 'RB, CDM, RWB' 'CM, RM, LM' 'LM, CM, RM' 'LB, RB, CDM'
#  'RB, RM, ST' 'CF, LM, RM' 'CM, ST, LM' 'CM, RM, CF' 'CB, CM, LB'
#  'RB, LB, CM' 'LWB, CB, LM' 'CB, LM, LB' 'RM, RWB, CM' 'LM, RB, CB'
#  'RM, ST, RWB' 'CDM, RM, LM' 'RW, CM, CAM' 'CF, CAM, LW' 'RM, RB, LM'
#  'CF, ST, CM' 'LB, LWB, CM' 'CM, RW, LM' 'RB, RWB, RW' 'ST, CB, CAM'
#  'LM, CF, CAM' 'LM, LB, ST' 'RB, RW, RWB' 'RM, RB, RW' 'RWB, CB, CM'
#  'RWB, RM, LM' 'ST, CB' 'CM, LB, LM' 'LW, RB, LB' 'LB, RW, LW' 'RW, RB'
#  'LWB, ST, CF' 'RW, RM, RWB' 'CB, ST' 'RWB, LM' 'CM, LM, RW' 'RM, CF, CM'
#  'LM, LB, CDM' 'CB, LWB, LB' 'RM, RW, CF' 'RB, CDM, CAM' 'LW, RM, RW'
#  'CM, RWB' 'RW, RM, LB' 'CB, CF' 'RB, ST, RM' 'LM, LW, CDM' 'CB, CAM'
#  'RM, RB, CDM' 'LM, LW, LWB' 'CM, RWB, LWB' 'LWB, CB' 'RB, LW'
#  'CM, CDM, RW' 'RB, RWB, CM' 'CB, RWB' 'LB, CM, CDM' 'RM, RB, ST'
#  'LW, CM, RW' 'CB, RM' 'CDM, LB, LM' 'CM, CAM, RB' 'CAM, RM, CDM'
#  'RM, CAM, RWB' 'RW, LM' 'CB, LM, ST' 'CM, ST, RM' 'CM, CAM, LW'
#  'RB, ST, RW' 'LB, CM, RB' 'CAM, LB' 'RM, RB, CAM' 'RM, LWB, ST'
#  'ST, CB, RB' 'RB, CAM' 'CM, CB, RB' 'CM, CDM, ST' 'RM, RW, RWB'
#  'RM, CB, RB' 'RWB, RB, CDM' 'RW, CM, LB' 'RM, CF, RB' 'RM, CM, CF'
#  'LB, LM, CDM' 'CDM, CAM, RB' 'CM, LW, ST' 'RM, CB' 'CM, LB, RM'
#  'LB, CDM, LM' 'CDM, LB, RM' 'LM, CM, RB' 'LW, CM, RB' 'RM, LWB, LM'
#  'LWB, CAM, LM' 'CM, RB, LM' 'LWB, CB, LB' 'ST, CM, CAM' 'LWB, LW'
#  'RM, RWB, RW' 'RW, CM, ST' 'CAM, ST, RB' 'CDM, LB, RB' 'RWB, CM'
#  'LB, CB, RM' 'CF, RM, CM' 'RWB, LWB, CB' 'ST, RM, RWB' 'LM, ST, CM'
#  'CM, LM, CB' 'LWB, LW, ST' 'CM, CF, RB' 'ST, RW, RB' 'RW, LM, CAM'
#  'RW, RB, LB' 'RWB, CDM' 'LW, LWB, LB' 'RB, ST' 'ST, LW, CDM'
#  'LB, CDM, RB' 'CM, RWB, CDM' 'LM, CDM, LWB' 'RM, ST, CM']
# CB              2322
# GK              2036
# ST              1809
# CM               786
# CDM, CM          731
#                 ...
# LM, LWB, CM        1
# CAM, CDM, CB       1
# RM, LB             1
# LB, CDM, LWB       1
# RM, ST, CM         1
# Name: player_positions, Length: 643, dtype: int64
# *************************
# preferred_foot ['Left' 'Right']
# Right    13960
# Left      4318
# Name: preferred_foot, dtype: int64
# *************************
# international_reputation [5 3 4 2 1]
# 1    16794
# 2     1140
# 3      292
# 4       46
# 5        6
# Name: international_reputation, dtype: int64
# *************************
# weak_foot [4 5 3 2 1]
# 3    11347
# 2     3865
# 4     2666
# 5      245
# 1      155
# Name: weak_foot, dtype: int64
# *************************
# skill_moves [4 5 1 2 3]
# 2    8617
# 3    6536
# 1    2036
# 4    1040
# 5      49
# Name: skill_moves, dtype: int64
# *************************
# work_rate ['Medium/Low' 'High/Low' 'High/Medium' 'Medium/Medium' 'High/High'
#  'Medium/High' 'Low/High' 'Low/Medium' 'Low/Low']
# Medium/Medium    9875
# High/Medium      3216
# Medium/High      1718
# High/High         986
# Medium/Low        886
# High/Low          684
# Low/Medium        461
# Low/High          417
# Low/Low            35
# Name: work_rate, dtype: int64
# *************************
# body_type ['Messi' 'C. Ronaldo' 'Neymar' 'Normal' 'Lean' 'PLAYER_BODY_TYPE_25'
#  'Stocky' 'Courtois' 'Shaqiri' 'Akinfenwa']
# Normal                 10750
# Lean                    6505
# Stocky                  1016
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# PLAYER_BODY_TYPE_25        1
# Courtois                   1
# Shaqiri                    1
# Akinfenwa                  1
# Name: body_type, dtype: int64
# *************************
# real_face ['Yes' 'No']
# No     16310
# Yes     1968
# Name: real_face, dtype: int64
# *************************
# release_clause_eur [1.958e+08 9.650e+07 1.952e+08 ... 4.000e+04 6.000e+04 5.900e+04]
# 1100000.0      535
# 1300000.0      447
# 1200000.0      402
# 1400000.0      394
# 1500000.0      344
#               ...
# 40200000.0       1
# 527000.0         1
# 32000000.0       1
# 38800000.0       1
# 195800000.0      1
# Name: release_clause_eur, Length: 1224, dtype: int64
# *************************
# player_tags ['#Dribbler, #Distance Shooter, #Crosser, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Forward'
#  '#Speedster, #Dribbler, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward'
#  '#Speedster, #Dribbler, #Playmaker\xa0 , #Crosser, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Midfielder, #Complete Forward'
#  nan '#Speedster, #Dribbler, #Acrobat'
#  '#Dribbler, #Playmaker\xa0 , #Engine, #Distance Shooter, #Crosser, #Complete Midfielder'
#  '#Tackling\xa0, #Tactician\xa0, #Strength, #Complete Defender'
#  '#Dribbler, #Playmaker\xa0 , #Crosser, #Acrobat, #Complete Midfielder'
#  '#Speedster, #Dribbler, #Acrobat, #Clinical Finisher, #Complete Forward'
#  '#Engine, #Distance Shooter, #Clinical Finisher'
#  '#Tackling\xa0, #Tactician\xa0'
#  '#Dribbler, #Clinical Finisher, #Complete Forward'
#  '#Aerial Threat, #Tackling\xa0, #Tactician\xa0, #Complete Defender'
#  '#Distance Shooter, #Strength, #Clinical Finisher, #Complete Forward'
#  '#Clinical Finisher' '#Playmaker\xa0 , #Tactician\xa0'
#  '#Dribbler, #Engine, #Acrobat, #Clinical Finisher, #Complete Forward'
#  '#Dribbler, #Playmaker\xa0 , #FK Specialist, #Acrobat, #Complete Midfielder'
#  '#Dribbler, #Playmaker\xa0 , #Strength, #Complete Midfielder'
#  '#Playmaker\xa0 , #Engine, #Crosser, #FK Specialist, #Complete Midfielder'
#  '#Aerial Threat, #Tackling\xa0, #Tactician\xa0, #Strength, #Complete Defender'
#  '#Dribbler, #Playmaker\xa0 , #Acrobat, #Complete Midfielder' '#Engine'
#  '#Playmaker\xa0 , #Crosser, #Complete Midfielder'
#  '#Dribbler, #Playmaker\xa0 , #Distance Shooter, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Midfielder, #Complete Forward'
#  '#Poacher, #Speedster, #Complete Forward' '#Dribbler, #Engine, #Acrobat'
#  '#Dribbler, #Engine, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward'
#  '#Tactician\xa0'
#  '#Dribbler, #Acrobat, #Clinical Finisher, #Complete Forward'
#  '#Speedster, #Crosser, #Acrobat' '#Dribbler, #Crosser, #Acrobat'
#  '#Crosser' '#Dribbler'
#  '#Dribbler, #Playmaker\xa0 , #Engine, #Complete Midfielder'
#  '#Dribbler, #Playmaker\xa0 , #FK Specialist, #Complete Midfielder'
#  '#Dribbler, #Crosser, #FK Specialist, #Acrobat'
#  '#Dribbler, #FK Specialist, #Acrobat'
#  '#Playmaker\xa0 , #FK Specialist, #Complete Midfielder'
#  '#Engine, #Clinical Finisher' '#Strength'
#  '#Dribbler, #Playmaker\xa0 , #Complete Midfielder' '#Tackling\xa0'
#  '#Aerial Threat, #Tackling\xa0, #Strength'
#  '#Playmaker\xa0 , #Engine, #Distance Shooter, #Crosser, #FK Specialist, #Complete Midfielder'
#  '#Poacher' '#Playmaker\xa0 , #Acrobat'
#  '#Poacher, #Aerial Threat, #Distance Shooter, #Strength, #Clinical Finisher, #Complete Forward'
#  '#Acrobat' '#Speedster, #Distance Shooter, #Crosser, #FK Specialist'
#  '#Dribbler, #Crosser' '#Acrobat, #Clinical Finisher' '#Engine, #Crosser'
#  '#Playmaker\xa0 , #Distance Shooter, #Crosser, #FK Specialist, #Complete Midfielder'
#  '#Dribbler, #Acrobat' '#Speedster, #Dribbler' '#FK Specialist'
#  '#Playmaker\xa0 ' '#Tackling\xa0, #Strength' '#Aerial Threat, #Strength'
#  '#Engine, #Tackling\xa0' '#Speedster, #Engine' '#Distance Shooter'
#  '#Poacher, #Clinical Finisher' '#Speedster, #Engine, #Acrobat'
#  '#Speedster' '#Speedster, #Acrobat'
#  '#Strength, #Clinical Finisher, #Complete Forward'
#  '#Distance Shooter, #Clinical Finisher'
#  '#Engine, #Tackling\xa0, #Tactician\xa0'
#  '#Engine, #Crosser, #FK Specialist' '#Aerial Threat'
#  '#Distance Shooter, #Crosser, #FK Specialist'
#  '#Poacher, #Aerial Threat, #Strength, #Complete Forward'
#  '#Engine, #Tactician\xa0' '#Engine, #Acrobat' '#Dribbler, #Strength'
#  '#Engine, #Strength' '#Dribbler, #Engine, #Crosser'
#  '#Aerial Threat, #Engine' '#Distance Shooter, #FK Specialist'
#  '#Distance Shooter, #Strength' '#Crosser, #FK Specialist'
#  '#Acrobat, #Strength']
# #Strength                                                                                    514
# #Acrobat                                                                                     238
# #Engine                                                                                      209
# #Speedster                                                                                   156
# #Speedster, #Acrobat                                                                          66
#                                                                                             ...
# #Speedster, #Dribbler, #Distance Shooter, #Acrobat, #Clinical Finisher, #Complete Forward      1
# #Aerial Threat, #Tackling , #Strength                                                          1
# #Playmaker  , #Engine, #Distance Shooter, #Crosser, #FK Specialist, #Complete Midfielder       1
# #Playmaker  , #Acrobat                                                                         1
# #Acrobat, #Strength                                                                            1
# Name: player_tags, Length: 83, dtype: int64
# *************************
# team_position ['RW' 'LW' 'CAM' 'GK' 'RCM' 'LCB' 'ST' 'CDM' 'LDM' 'RM' 'RCB' 'LCM' 'LM'
#  'CF' 'SUB' 'LB' 'LS' 'RB' 'RDM' 'RES' 'RAM' 'RS' 'RF' 'CM' 'CB' 'LF'
#  'LAM' nan 'RWB' 'LWB']
# SUB    7820
# RES    2958
# GK      662
# RCB     660
# LCB     660
# RB      560
# LB      560
# ST      458
# RCM     411
# LCM     411
# RM      399
# LM      398
# CAM     311
# RDM     244
# LDM     242
# RS      195
# LS      195
# CDM     181
# LW      162
# RW      161
# CB      100
# CM       76
# RWB      58
# LWB      58
# RAM      23
# LAM      23
# RF       19
# LF       19
# CF       14
# Name: team_position, dtype: int64
# *************************
# team_jersey_number [10.  7. 13. 17.  1.  4. 11. 26.  3.  9.  5.  6. 31. 23. 21.  2.  8. 14.
#  20. 25. 15. 18. 24. 19. 37. 32. 22. 99. 16. 44. 27. 36. 12. 28. 29. 39.
#  72. 66. 33. 77. 30. 40. 58. 45. 38. 91. nan 34. 47. 81. 35. 89. 79. 71.
#  83. 87. 41. 97. 59. 57. 93. 88. 70. 90. 67. 49. 62. 61. 95. 73. 98. 60.
#  42. 80. 94. 56. 43. 55. 75. 78. 92. 74. 69. 76. 51. 50. 82. 63. 46. 68.
#  64. 96. 54. 52. 84. 53. 48. 86. 65. 85.]
# 7.0     599
# 8.0     596
# 11.0    582
# 10.0    581
# 5.0     580
#        ...
# 83.0      4
# 86.0      3
# 65.0      3
# 85.0      3
# 79.0      2
# Name: team_jersey_number, Length: 99, dtype: int64
# *************************
# loaned_from [nan 'FC Barcelona' 'Inter' 'Real Betis' 'Chelsea' 'Sampdoria'
#  'Real Madrid' 'Real Sociedad' 'Cagliari' 'FC Schalke 04' 'Roma'
#  'Fiorentina' 'Valencia CF' 'Liverpool' 'Borussia Dortmund' 'Lazio'
#  'Sevilla FC' 'Guangzhou Evergrande Taobao FC' 'Villarreal CF' 'Fulham'
#  'FC Girondins de Bordeaux' 'Defensa y Justicia' 'Sassuolo' 'AS Monaco'
#  'Racing Club' 'SL Benfica' 'Atalanta' 'Manchester City' 'Sporting CP'
#  'Monterrey' 'Frosinone' 'Bournemouth' 'Huddersfield Town' 'Bologna'
#  'Napoli' 'Brighton & Hove Albion' 'Al Ittihad' 'Manchester United'
#  'Levante UD' 'Everton' 'Eintracht Frankfurt' 'Wolverhampton Wanderers'
#  'Deportivo Cali' 'Club León' 'Antalyaspor' 'Olympique de Marseille'
#  'Girona FC' 'Udinese' 'Independiente' 'Olympique Lyonnais'
#  'VfB Stuttgart' 'Estudiantes de La Plata' 'FC Porto'
#  'En Avant de Guingamp' 'TSG 1899 Hoffenheim' 'LOSC Lille'
#  'FC Midtjylland' 'Rayo Vallecano' 'SC Braga' 'Club Atlas'
#  'Guangzhou R&F FC' 'Jiangsu Suning FC' 'Club Tijuana' 'Atlético Nacional'
#  'Torino' 'Crystal Palace' 'Getafe CF' 'Trabzonspor' 'Chievo Verona'
#  'Watford' 'FC Nantes' 'Independiente Santa Fe' 'FC Metz' 'Cardiff City'
#  'Pescara' 'Santos Laguna' 'Tigres U.A.N.L.' 'Club Atlético Lanús'
#  'SD Huesca' 'Sanfrecce Hiroshima' 'Bahia' 'Genoa' 'Millonarios FC'
#  'Boca Juniors' 'RC Celta' 'Milan' '1. FC Köln' 'Vitória Guimarães'
#  'Gimnasia y Esgrima La Plata' 'Querétaro' 'Deportivo Toluca'
#  'Derby County' 'Swansea City' 'Sheffield United' 'Puebla FC' 'Junior FC'
#  'River Plate' 'Arsenal' 'FC Augsburg' 'Southampton' 'Godoy Cruz'
#  'Fenerbahçe SK' 'Angers SCO' 'San Lorenzo de Almagro' 'Beşiktaş JK'
#  '1. FSV Mainz 05' 'Newcastle United' 'Guadalajara' 'Club Atlético Colón'
#  'SC Freiburg' 'Pachuca' 'Sint-Truidense VV' 'Club Atlético Talleres'
#  'Stoke City' 'Toulouse Football Club' 'West Ham United' 'Cruz Azul'
#  'Blackburn Rovers' 'Hellas Verona' 'Bristol City' 'Parma' 'Empoli'
#  'FC Bayern München' 'Argentinos Juniors' 'Athletic Club de Bilbao'
#  'OGC Nice' 'RCD Espanyol' 'Atlético Madrid' 'RCD Mallorca' 'SD Eibar'
#  'AS Saint-Étienne' 'RSC Anderlecht' 'Universidad Católica'
#  'Standard de Liège' 'CSA - AL' 'FC Utrecht' 'RC Strasbourg Alsace'
#  'Rosario Central' 'Aston Villa' 'Ipswich Town' 'Internacional'
#  'SV Zulte-Waregem' 'Burnley' 'Pohang Steelers' 'Benevento' 'Al Ahli'
#  'Independiente Medellín' 'Matsumoto Yamaga' 'Stade Malherbe Caen' 'PSV'
#  'Hertha BSC' 'Tottenham Hotspur' 'FC Basel 1893' 'KRC Genk'
#  'Deportivo Alavés' 'Club Brugge KV' 'Ajax' 'Malmö FF'
#  'Real Valladolid CF' 'Hamburger SV' 'FC Red Bull Salzburg' 'CD Leganés'
#  'Feyenoord' 'Rio Ave FC' 'Spezia' 'Minnesota United FC'
#  'Universidad de Chile' 'Atlético Tucumán' 'Preston North End' 'Vitesse'
#  'Reading' '1. FC Magdeburg' 'Leicester City' 'AD Alcorcón'
#  'América de Cali' 'Vélez Sarsfield' 'Club América' 'Rangers FC'
#  'Fortuna Düsseldorf' 'La Equidad' 'Columbus Crew SC' 'CD Numancia'
#  'Cádiz CF' 'Stade Rennais FC' 'VfL Wolfsburg' 'Sporting de Charleroi'
#  'Vancouver Whitecaps FC' 'FC Paços de Ferreira' 'Deportivo de La Coruña'
#  'Jeonbuk Hyundai Motors' 'Holstein Kiel' 'Nottingham Forest'
#  'Albacete BP' 'KSV Cercle Brugge' 'FC Ingolstadt 04' 'FC Lorient' 'SPAL'
#  'West Bromwich Albion' 'New York Red Bulls' 'SV Werder Bremen'
#  'Montreal Impact' 'Leeds United' 'Colo-Colo' 'CFR Cluj' 'Norwich City'
#  'Rosenborg BK' 'Envigado FC' 'Urawa Red Diamonds' 'Sheffield Wednesday'
#  'Jaguares de Córdoba' 'Patriotas Boyacá FC' 'Real Salt Lake'
#  'Once Caldas' 'CD Everton de Viña del Mar' 'Racing Club de Lens'
#  'Rotherham United' 'Molde FK' 'Jeju United FC' 'Unión La Calera'
#  'LA Galaxy' 'Suwon Samsung Bluewings' 'Tianjin Quanjian FC'
#  'Arsenal de Sarandí' 'US Cremonese' 'Yokohama F. Marinos'
#  'Shimizu S-Pulse' 'SpVgg Greuther Fürth' 'U.N.A.M.' 'Wigan Athletic'
#  'SV Sandhausen' 'Atlético de San Luis' 'Östersunds FK' 'Nagoya Grampus'
#  'LASK Linz' 'Universitatea Craiova' "CD O'Higgins" 'SK Sturm Graz'
#  'Gamba Osaka' 'Kawasaki Frontale' 'Club Atlético Banfield'
#  'FCSB (Steaua)' 'Borussia Mönchengladbach' 'Willem II' 'CA Osasuna'
#  'Hull City' 'Birmingham City' '1. FC Kaiserslautern' 'Plymouth Argyle'
#  'Pisa' 'UD Las Palmas' 'Galatasaray SK' 'Kashima Antlers'
#  'SSV Jahn Regensburg' 'Hebei China Fortune FC' 'Incheon United FC'
#  'Vålerenga Fotball' 'FC Erzgebirge Aue' 'Paris Saint-Germain' 'FC Luzern'
#  'Queens Park Rangers' '1. FC Heidenheim 1846' 'Scunthorpe United'
#  'IFK Norrköping' 'AC Horsens' 'Daegu FC' 'Perugia' 'Crewe Alexandra'
#  'Cork City' 'Bradford City' 'Gyeongnam FC' 'Colorado Rapids' 'Gangwon FC'
#  'Beijing Sinobo Guoan FC' "Newell's Old Boys" 'RB Leipzig'
#  '1. FC Union Berlin' 'Al Nassr' 'Barnsley' 'Hannover 96' 'Portsmouth'
#  'SC Paderborn 07' 'Djurgårdens IF' 'Bristol Rovers' 'Middlesbrough'
#  'Celtic' 'FC Viitorul' 'SK Rapid Wien' 'Jagiellonia Białystok'
#  'Dinamo Bucureşti' 'Ulsan Hyundai FC' 'Lech Poznań' 'Júbilo Iwata'
#  'Shamrock Rovers' 'Karlsruher SC' 'Cerezo Osaka' 'Zagłębie Lubin'
#  'Aalborg BK' 'Atlético Huila' 'Club Necaxa' 'Fleetwood Town' 'Brøndby IF'
#  'Ettifaq FC' 'Colchester United' '1. FC Nürnberg' 'Brentford'
#  'BSC Young Boys' 'Legia Warszawa' 'Al Shabab'
#  'Shandong Luneng TaiShan FC' 'Millwall' 'Kilmarnock' 'Atlanta United'
#  'FC Zürich' 'Coventry City' 'Charlton Athletic' 'Accrington Stanley'
#  'Tianjin TEDA FC']
# Sassuolo               17
# Atalanta               17
# Inter                  14
# SL Benfica             14
# Racing Club            13
#                        ..
# Shimizu S-Pulse         1
# US Cremonese            1
# Arsenal de Sarandí      1
# Tianjin Quanjian FC     1
# Tianjin TEDA FC         1
# Name: loaned_from, Length: 316, dtype: int64
# *************************
# joined ['2004-07-01' '2018-07-10' '2017-08-03' ... '2018-10-29' '2019-05-22'
#  '2016-11-20']
# 2019-07-01    1465
# 2018-07-01    1213
# 2017-07-01     750
# 2016-07-01     434
# 2015-07-01     272
#               ...
# 2017-02-16       1
# 2012-06-07       1
# 2005-06-01       1
# 2011-03-11       1
# 2016-11-20       1
# Name: joined, Length: 1760, dtype: int64
# *************************
# contract_valid_until [2021. 2022. 2023. 2024. 2020. 2026. 2019. 2025.   nan]
# 2020.0    6131
# 2021.0    4133
# 2022.0    3982
# 2023.0    1740
# 2019.0    1088
# 2024.0     947
# 2025.0      14
# 2026.0       3
# Name: contract_valid_until, dtype: int64
# *************************
# nation_position [nan 'LS' 'LW' 'GK' 'LF' 'RCM' 'SUB' 'LCB' 'RW' 'RM' 'ST' 'LDM' 'RCB'
#  'CDM' 'CAM' 'CF' 'RDM' 'RF' 'LB' 'LCM' 'LM' 'RB' 'CB' 'CM' 'RS' 'RWB'
#  'LWB']
# SUB    587
# LCB     49
# GK      49
# RCB     49
# LB      46
# RB      46
# ST      43
# LCM     36
# RCM     36
# RM      29
# LM      29
# CAM     22
# CDM     21
# RW      19
# LW      19
# LDM     12
# RDM     12
# RS       6
# LS       6
# CB       3
# CM       2
# RF       1
# CF       1
# LF       1
# RWB      1
# LWB      1
# Name: nation_position, dtype: int64
# *************************
# nation_jersey_number [nan  7. 10.  1. 22.  4.  9. 13.  3. 15.  5. 21.  6.  8. 11. 14.  2. 18.
#  19. 17. 16. 23. 20. 12. 24. 29. 26. 28. 25. 27. 30.]
# 2.0     49
# 18.0    49
# 1.0     49
# 12.0    49
# 20.0    49
# 9.0     49
# 23.0    49
# 3.0     49
# 15.0    49
# 21.0    49
# 6.0     49
# 17.0    49
# 19.0    49
# 14.0    49
# 16.0    48
# 7.0     48
# 10.0    48
# 11.0    48
# 8.0     48
# 5.0     48
# 13.0    48
# 4.0     48
# 22.0    48
# 24.0     2
# 29.0     1
# 26.0     1
# 28.0     1
# 25.0     1
# 27.0     1
# 30.0     1
# Name: nation_jersey_number, dtype: int64
# *************************
# ...
#  '73+3' '57+2' '77+3' '61+2' '75+2' '72+2' '73+2' '59+2' '72+3' '63+2'
#  '65+2' '64+2' '69+2' '74+2' '71+2' '52+2' '70+2' '60+3' '55+3' '62+2'
#  '68+2' '53+2' '56+2' '55+2' '63+3' '51+3' '45+3' '49+3' '50+2' '45+2'
#  '47+2' '49+2' '48+2' '43+2' '40+2' '42+2' '44+2' '46+2' '41+2' '37+2'
#  '39+2' '36+2' '52+3' '38+2' '35+2' '34+2' '33+2' '32+2' '30+2' '31+2'
#  '29+2' '28+2' '27+2']
# 61+2    748
# 62+2    736
# 63+2    736
# 64+2    680
# 60+2    671
#        ...
# 85+2      1
# 84+5      1
# 89+3      1
# 90+3      1
# 27+2      1
# Name: lam, Length: 103, dtype: int64
# *************************
# cam ['93+2' '88+3' '90+3' nan '89+3' '69+3' '86+3' '87+3' '58+3' '83+3' '78+3'
#  '56+3' '85+3' '74+3' '84+5' '84+3' '71+3' '80+3' '61+3' '81+3' '67+2'
#  '85+2' '70+3' '67+3' '83+2' '68+3' '60+2' '80+2' '82+3' '66+3' '64+3'
#  '54+2' '82+2' '78+2' '76+3' '76+2' '51+2' '66+2' '84+2' '75+3' '50+3'
#  '80+4' '81+2' '79+2' '79+3' '62+3' '59+3' '57+3' '65+3' '58+2' '77+2'
#  '73+3' '57+2' '77+3' '61+2' '75+2' '72+2' '73+2' '59+2' '72+3' '63+2'
#  '65+2' '64+2' '69+2' '74+2' '71+2' '52+2' '70+2' '60+3' '55+3' '62+2'
#  '68+2' '53+2' '56+2' '55+2' '63+3' '51+3' '45+3' '49+3' '50+2' '45+2'
#  '47+2' '49+2' '48+2' '43+2' '40+2' '42+2' '44+2' '46+2' '41+2' '37+2'
#  '39+2' '36+2' '52+3' '38+2' '35+2' '34+2' '33+2' '32+2' '30+2' '31+2'
#  '29+2' '28+2' '27+2']
# 61+2    748
# 62+2    736
# 63+2    736
# 64+2    680
# 60+2    671
#        ...
# 85+2      1
# 84+5      1
# 89+3      1
# 90+3      1
# 27+2      1
# Name: cam, Length: 103, dtype: int64
# *************************
# ram ['93+2' '88+3' '90+3' nan '89+3' '69+3' '86+3' '87+3' '58+3' '83+3' '78+3'
#  '56+3' '85+3' '74+3' '84+5' '84+3' '71+3' '80+3' '61+3' '81+3' '67+2'
#  '85+2' '70+3' '67+3' '83+2' '68+3' '60+2' '80+2' '82+3' '66+3' '64+3'
#  '54+2' '82+2' '78+2' '76+3' '76+2' '51+2' '66+2' '84+2' '75+3' '50+3'
#  '80+4' '81+2' '79+2' '79+3' '62+3' '59+3' '57+3' '65+3' '58+2' '77+2'
#  '73+3' '57+2' '77+3' '61+2' '75+2' '72+2' '73+2' '59+2' '72+3' '63+2'
#  '65+2' '64+2' '69+2' '74+2' '71+2' '52+2' '70+2' '60+3' '55+3' '62+2'
#  '68+2' '53+2' '56+2' '55+2' '63+3' '51+3' '45+3' '49+3' '50+2' '45+2'
#  '47+2' '49+2' '48+2' '43+2' '40+2' '42+2' '44+2' '46+2' '41+2' '37+2'
#  '39+2' '36+2' '52+3' '38+2' '35+2' '34+2' '33+2' '32+2' '30+2' '31+2'
#  '29+2' '28+2' '27+2']
# 61+2    748
# 62+2    736
# 63+2    736
# 64+2    680
# 60+2    671
#        ...
# 85+2      1
# 84+5      1
# 89+3      1
# 90+3      1
# 27+2      1
# Name: ram, Length: 103, dtype: int64
# *************************
# lm ['92+2' '88+3' '89+3' nan '69+3' '85+3' '87+3' '86+3' '60+3' '82+3' '79+3'
#  '57+3' '83+3' '73+3' '82+5' '80+3' '75+3' '61+3' '81+3' '67+2' '86+2'
#  '72+3' '76+3' '68+3' '70+3' '67+3' '83+2' '62+2' '65+3' '77+2' '64+3'
#  '54+2' '79+2' '76+2' '84+2' '53+3' '78+3' '75+4' '84+3' '81+2' '82+2'
#  '59+3' '63+3' '66+3' '77+3' '58+3' '58+2' '78+2' '80+2' '57+2' '68+2'
#  '61+2' '72+2' '75+2' '71+3' '55+3' '62+3' '74+3' '59+2' '71+2' '65+2'
#  '53+2' '63+2' '73+2' '64+2' '66+2' '70+2' '74+2' '69+2' '60+2' '55+2'
#  '56+2' '52+3' '47+3' '51+2' '50+3' '52+2' '46+2' '50+2' '47+2' '44+2'
#  '49+2' '54+3' '48+2' '45+2' '43+2' '42+2' '38+2' '40+2' '41+2' '39+2'
#  '51+3' '36+2' '37+2' '35+2' '34+2' '33+2' '32+2' '30+2' '31+2' '27+2']
# 61+2    809
# 63+2    763
# 64+2    729
# 62+2    726
# 65+2    726
#        ...
# 84+2      1
# 86+2      1
# 82+5      1
# 87+3      1
# 27+2      1
# Name: lm, Length: 100, dtype: int64
# *************************
# lcm ['87+2' '81+3' '82+3' nan '83+3' '87+3' '74+3' '78+3' '65+3' '79+3' '62+3'
#  '77+3' '79+5' '80+3' '84+3' '85+3' '76+3' '75+3' '67+3' '74+2' '82+2'
#  '66+2' '72+3' '83+2' '70+3' '71+3' '69+3' '62+2' '81+2' '78+2' '58+2'
#  '72+2' '84+2' '55+3' '74+4' '75+2' '80+2' '73+2' '68+3' '64+3' '60+3'
#  '73+3' '79+2' '77+2' '65+2' '69+2' '64+2' '70+2' '71+2' '63+2' '76+2'
#  '66+3' '60+2' '67+2' '61+3' '61+2' '57+2' '59+2' '68+2' '53+3' '63+3'
#  '57+3' '54+2' '56+2' '53+2' '52+2' '55+2' '51+2' '58+3' '50+2' '47+2'
#  '49+2' '48+2' '45+2' '43+2' '44+2' '46+2' '41+2' '42+2' '40+2' '39+2'
#  '37+2' '38+2' '35+2' '36+2' '34+2' '33+2' '31+2' '32+2']
# 58+2    775
# 59+2    737
# 61+2    734
# 60+2    731
# 63+2    714
#        ...
# 84+2      1
# 55+3      1
# 74+4      1
# 53+3      1
# 87+2      1
# Name: lcm, Length: 88, dtype: int64
# *************************
# cm ['87+2' '81+3' '82+3' nan '83+3' '87+3' '74+3' '78+3' '65+3' '79+3' '62+3'
#  '77+3' '79+5' '80+3' '84+3' '85+3' '76+3' '75+3' '67+3' '74+2' '82+2'
#  '66+2' '72+3' '83+2' '70+3' '71+3' '69+3' '62+2' '81+2' '78+2' '58+2'
#  '72+2' '84+2' '55+3' '74+4' '75+2' '80+2' '73+2' '68+3' '64+3' '60+3'
#  '73+3' '79+2' '77+2' '65+2' '69+2' '64+2' '70+2' '71+2' '63+2' '76+2'
#  '66+3' '60+2' '67+2' '61+3' '61+2' '57+2' '59+2' '68+2' '53+3' '63+3'
#  '57+3' '54+2' '56+2' '53+2' '52+2' '55+2' '51+2' '58+3' '50+2' '47+2'
#  '49+2' '48+2' '45+2' '43+2' '44+2' '46+2' '41+2' '42+2' '40+2' '39+2'
#  '37+2' '38+2' '35+2' '36+2' '34+2' '33+2' '31+2' '32+2']
# 58+2    775
# 59+2    737
# 61+2    734
# 60+2    731
# 63+2    714
#        ...
# 84+2      1
# 55+3      1
# 74+4      1
# 53+3      1
# 87+2      1
# Name: cm, Length: 88, dtype: int64
# *************************
# rcm ['87+2' '81+3' '82+3' nan '83+3' '87+3' '74+3' '78+3' '65+3' '79+3' '62+3'
#  '77+3' '79+5' '80+3' '84+3' '85+3' '76+3' '75+3' '67+3' '74+2' '82+2'
#  '66+2' '72+3' '83+2' '70+3' '71+3' '69+3' '62+2' '81+2' '78+2' '58+2'
#  '72+2' '84+2' '55+3' '74+4' '75+2' '80+2' '73+2' '68+3' '64+3' '60+3'
#  '73+3' '79+2' '77+2' '65+2' '69+2' '64+2' '70+2' '71+2' '63+2' '76+2'
#  '66+3' '60+2' '67+2' '61+3' '61+2' '57+2' '59+2' '68+2' '53+3' '63+3'
#  '57+3' '54+2' '56+2' '53+2' '52+2' '55+2' '51+2' '58+3' '50+2' '47+2'
#  '49+2' '48+2' '45+2' '43+2' '44+2' '46+2' '41+2' '42+2' '40+2' '39+2'
#  '37+2' '38+2' '35+2' '36+2' '34+2' '33+2' '31+2' '32+2']
# 58+2    775
# 59+2    737
# 61+2    734
# 60+2    731
# 63+2    714
#        ...
# 84+2      1
# 55+3      1
# 74+4      1
# 53+3      1
# 87+2      1
# Name: rcm, Length: 88, dtype: int64
# *************************
# rm ['92+2' '88+3' '89+3' nan '69+3' '85+3' '87+3' '86+3' '60+3' '82+3' '79+3'
#  '57+3' '83+3' '73+3' '82+5' '80+3' '75+3' '61+3' '81+3' '67+2' '86+2'
#  '72+3' '76+3' '68+3' '70+3' '67+3' '83+2' '62+2' '65+3' '77+2' '64+3'
#  '54+2' '79+2' '76+2' '84+2' '53+3' '78+3' '75+4' '84+3' '81+2' '82+2'
#  '59+3' '63+3' '66+3' '77+3' '58+3' '58+2' '78+2' '80+2' '57+2' '68+2'
#  '61+2' '72+2' '75+2' '71+3' '55+3' '62+3' '74+3' '59+2' '71+2' '65+2'
#  '53+2' '63+2' '73+2' '64+2' '66+2' '70+2' '74+2' '69+2' '60+2' '55+2'
#  '56+2' '52+3' '47+3' '51+2' '50+3' '52+2' '46+2' '50+2' '47+2' '44+2'
#  '49+2' '54+3' '48+2' '45+2' '43+2' '42+2' '38+2' '40+2' '41+2' '39+2'
#  '51+3' '36+2' '37+2' '35+2' '34+2' '33+2' '32+2' '30+2' '31+2' '27+2']
# 61+2    809
# 63+2    763
# 64+2    729
# 62+2    726
# 65+2    726
#        ...
# 84+2      1
# 86+2      1
# 82+5      1
# 87+3      1
# 27+2      1
# Name: rm, Length: 100, dtype: int64
# *************************
# lwb ['68+2' '65+3' '66+3' nan '77+3' '79+3' '81+3' '70+3' '74+3' '85+3' '73+3'
#  '60+3' '80+3' '67+5' '61+3' '78+3' '68+3' '76+3' '71+3' '75+3' '69+3'
#  '64+3' '67+3' '78+2' '72+2' '62+3' '84+3' '63+3' '65+2' '74+2' '83+3'
#  '72+3' '71+2' '76+2' '83+2' '77+2' '57+3' '53+3' '53+4' '82+3' '60+2'
#  '84+2' '64+2' '59+2' '66+2' '59+3' '70+2' '75+2' '81+2' '55+2' '56+3'
#  '63+2' '61+2' '73+2' '82+2' '53+2' '54+2' '79+2' '80+2' '58+2' '55+3'
#  '62+2' '67+2' '56+2' '69+2' '52+3' '52+2' '57+2' '50+2' '58+3' '49+2'
#  '51+2' '44+2' '54+3' '48+2' '49+3' '50+3' '47+2' '45+2' '46+2' '48+3'
#  '44+3' '47+3' '43+2' '42+2' '41+2' '40+2' '51+3' '37+2' '43+3' '39+2'
#  '38+2' '36+2' '35+2' '34+2' '32+2' '33+2' '30+2' '31+2']
# 59+2    682
# 62+2    668
# 57+2    664
# 61+2    656
# 55+2    648
#        ...
# 50+3      1
# 84+2      1
# 47+3      1
# 44+3      1
# 43+3      1
# Name: lwb, Length: 98, dtype: int64
# *************************
# ldm ['66+2' '61+3' nan '63+3' '77+3' '83+3' '81+3' '67+3' '62+3' '79+3' '66+3'
#  '87+3' '58+3' '84+3' '67+5' '86+3' '71+3' '64+3' '69+3' '80+3' '65+3'
#  '82+2' '69+2' '82+3' '60+3' '78+3' '59+2' '79+2' '70+3' '73+3' '68+3'
#  '78+2' '57+3' '77+2' '80+2' '74+2' '81+2' '56+3' '74+3' '52+3' '57+4'
#  '57+2' '86+2' '58+2' '63+2' '59+3' '54+2' '62+2' '76+3' '72+3' '55+3'
#  '67+2' '75+3' '64+2' '75+2' '53+2' '76+2' '60+2' '55+2' '56+2' '70+2'
#  '68+2' '51+2' '61+2' '54+3' '65+2' '73+2' '53+3' '52+2' '72+2' '49+2'
#  '71+2' '50+2' '51+3' '48+2' '50+3' '46+2' '47+2' '45+2' '43+2' '46+3'
#  '48+3' '44+2' '42+2' '41+2' '39+2' '40+2' '38+2' '37+2' '44+3' '36+2'
#  '35+2' '34+2' '33+2' '32+2' '30+2' '31+2' '29+2' '28+2']
# 59+2    636
# 62+2    625
# 58+2    612
# 63+2    609
# 64+2    563
#        ...
# 48+3      1
# 87+3      1
# 46+3      1
# 57+4      1
# 86+2      1
# Name: ldm, Length: 98, dtype: int64
# *************************
# cdm ['66+2' '61+3' nan '63+3' '77+3' '83+3' '81+3' '67+3' '62+3' '79+3' '66+3'
#  '87+3' '58+3' '84+3' '67+5' '86+3' '71+3' '64+3' '69+3' '80+3' '65+3'
#  '82+2' '69+2' '82+3' '60+3' '78+3' '59+2' '79+2' '70+3' '73+3' '68+3'
#  '78+2' '57+3' '77+2' '80+2' '74+2' '81+2' '56+3' '74+3' '52+3' '57+4'
#  '57+2' '86+2' '58+2' '63+2' '59+3' '54+2' '62+2' '76+3' '72+3' '55+3'
#  '67+2' '75+3' '64+2' '75+2' '53+2' '76+2' '60+2' '55+2' '56+2' '70+2'
#  '68+2' '51+2' '61+2' '54+3' '65+2' '73+2' '53+3' '52+2' '72+2' '49+2'
#  '71+2' '50+2' '51+3' '48+2' '50+3' '46+2' '47+2' '45+2' '43+2' '46+3'
#  '48+3' '44+2' '42+2' '41+2' '39+2' '40+2' '38+2' '37+2' '44+3' '36+2'
#  '35+2' '34+2' '33+2' '32+2' '30+2' '31+2' '29+2' '28+2']
# 59+2    636
# 62+2    625
# 58+2    612
# 63+2    609
# 64+2    563
#        ...
# 48+3      1
# 87+3      1
# 46+3      1
# 57+4      1
# 86+2      1
# Name: cdm, Length: 98, dtype: int64
# *************************
# rdm ['66+2' '61+3' nan '63+3' '77+3' '83+3' '81+3' '67+3' '62+3' '79+3' '66+3'
#  '87+3' '58+3' '84+3' '67+5' '86+3' '71+3' '64+3' '69+3' '80+3' '65+3'
#  '82+2' '69+2' '82+3' '60+3' '78+3' '59+2' '79+2' '70+3' '73+3' '68+3'
#  '78+2' '57+3' '77+2' '80+2' '74+2' '81+2' '56+3' '74+3' '52+3' '57+4'
#  '57+2' '86+2' '58+2' '63+2' '59+3' '54+2' '62+2' '76+3' '72+3' '55+3'
#  '67+2' '75+3' '64+2' '75+2' '53+2' '76+2' '60+2' '55+2' '56+2' '70+2'
#  '68+2' '51+2' '61+2' '54+3' '65+2' '73+2' '53+3' '52+2' '72+2' '49+2'
#  '71+2' '50+2' '51+3' '48+2' '50+3' '46+2' '47+2' '45+2' '43+2' '46+3'
#  '48+3' '44+2' '42+2' '41+2' '39+2' '40+2' '38+2' '37+2' '44+3' '36+2'
#  '35+2' '34+2' '33+2' '32+2' '30+2' '31+2' '29+2' '28+2']
# 59+2    636
# 62+2    625
# 58+2    612
# 63+2    609
# 64+2    563
#        ...
# 48+3      1
# 87+3      1
# 46+3      1
# 57+4      1
# 86+2      1
# Name: rdm, Length: 98, dtype: int64
# *************************
# rwb ['68+2' '65+3' '66+3' nan '77+3' '79+3' '81+3' '70+3' '74+3' '85+3' '73+3'
#  '60+3' '80+3' '67+5' '61+3' '78+3' '68+3' '76+3' '71+3' '75+3' '69+3'
#  '64+3' '67+3' '78+2' '72+2' '62+3' '84+3' '63+3' '65+2' '74+2' '83+3'
#  '72+3' '71+2' '76+2' '83+2' '77+2' '57+3' '53+3' '53+4' '82+3' '60+2'
#  '84+2' '64+2' '59+2' '66+2' '59+3' '70+2' '75+2' '81+2' '55+2' '56+3'
#  '63+2' '61+2' '73+2' '82+2' '53+2' '54+2' '79+2' '80+2' '58+2' '55+3'
#  '62+2' '67+2' '56+2' '69+2' '52+3' '52+2' '57+2' '50+2' '58+3' '49+2'
#  '51+2' '44+2' '54+3' '48+2' '49+3' '50+3' '47+2' '45+2' '46+2' '48+3'
#  '44+3' '47+3' '43+2' '42+2' '41+2' '40+2' '51+3' '37+2' '43+3' '39+2'
#  '38+2' '36+2' '35+2' '34+2' '32+2' '33+2' '30+2' '31+2']
# 59+2    682
# 62+2    668
# 57+2    664
# 61+2    656
# 55+2    648
#        ...
# 50+3      1
# 84+2      1
# 47+3      1
# 44+3      1
# 43+3      1
# Name: rwb, Length: 98, dtype: int64
# *************************
# lb ['63+2' '61+3' nan '73+3' '81+3' '79+3' '66+3' '63+3' '77+3' '62+3' '84+3'
#  '76+3' '56+3' '82+3' '64+5' '58+3' '78+3' '70+3' '64+3' '74+3' '72+3'
#  '80+2' '67+2' '80+3' '60+3' '75+3' '61+2' '76+2' '67+3' '69+3' '71+2'
#  '57+3' '59+3' '75+2' '78+2' '82+2' '74+2' '79+2' '54+3' '51+3' '83+3'
#  '50+4' '49+3' '56+2' '83+2' '59+2' '62+2' '60+2' '55+2' '68+3' '55+3'
#  '64+2' '71+3' '65+2' '72+2' '51+2' '66+2' '73+2' '57+2' '77+2' '81+2'
#  '50+2' '53+2' '53+3' '70+2' '65+3' '58+2' '69+2' '54+2' '52+3' '68+2'
#  '49+2' '50+3' '48+2' '52+2' '47+2' '43+2' '46+2' '47+3' '44+2' '42+2'
#  '45+2' '46+3' '41+2' '41+3' '45+3' '40+2' '38+2' '39+2' '36+2' '37+2'
#  '35+2' '32+2' '34+2' '33+2' '31+2' '30+2']
# 61+2    667
# 63+2    660
# 62+2    642
# 59+2    639
# 60+2    598
#        ...
# 45+3      1
# 64+5      1
# 46+3      1
# 50+4      1
# 83+2      1
# Name: lb, Length: 96, dtype: int64
# *************************
# lcb ['52+2' '53+3' '46+3' nan '49+3' '66+3' '87+3' '72+3' '57+3' '54+3' '86+3'
#  '60+3' '83+3' '50+3' '63+5' '82+3' '65+3' '51+3' '85+3' '56+3' '69+3'
#  '55+3' '85+2' '57+2' '84+3' '78+3' '44+3' '84+2' '76+3' '62+3' '67+3'
#  '73+3' '58+3' '69+2' '83+2' '79+2' '80+2' '77+2' '68+2' '80+3' '52+4'
#  '48+3' '47+3' '81+3' '79+3' '49+2' '74+3' '47+2' '54+2' '76+2' '73+2'
#  '51+2' '43+2' '53+2' '59+3' '70+3' '71+3' '39+3' '56+2' '52+3' '81+2'
#  '63+2' '46+2' '78+2' '64+3' '61+3' '45+2' '62+2' '58+2' '71+2' '75+3'
#  '68+3' '82+2' '55+2' '50+2' '48+2' '66+2' '59+2' '42+3' '74+2' '45+3'
#  '60+2' '63+3' '67+2' '70+2' '64+2' '75+2' '40+3' '41+2' '38+2' '39+2'
#  '72+2' '65+2' '61+2' '77+3' '44+2' '42+2' '40+2' '43+3' '37+2' '36+2'
#  '34+2' '33+2' '32+2' '35+2' '31+2' '29+2' '26+2' '30+2' '28+2' '27+2']
# 63+2    621
# 62+2    609
# 64+2    599
# 61+2    554
# 66+2    545
#        ...
# 40+3      1
# 85+2      1
# 52+4      1
# 39+3      1
# 84+2      1
# Name: lcb, Length: 110, dtype: int64
# *************************
# cb ['52+2' '53+3' '46+3' nan '49+3' '66+3' '87+3' '72+3' '57+3' '54+3' '86+3'
#  '60+3' '83+3' '50+3' '63+5' '82+3' '65+3' '51+3' '85+3' '56+3' '69+3'
#  '55+3' '85+2' '57+2' '84+3' '78+3' '44+3' '84+2' '76+3' '62+3' '67+3'
#  '73+3' '58+3' '69+2' '83+2' '79+2' '80+2' '77+2' '68+2' '80+3' '52+4'
#  '48+3' '47+3' '81+3' '79+3' '49+2' '74+3' '47+2' '54+2' '76+2' '73+2'
#  '51+2' '43+2' '53+2' '59+3' '70+3' '71+3' '39+3' '56+2' '52+3' '81+2'
#  '63+2' '46+2' '78+2' '64+3' '61+3' '45+2' '62+2' '58+2' '71+2' '75+3'
#  '68+3' '82+2' '55+2' '50+2' '48+2' '66+2' '59+2' '42+3' '74+2' '45+3'
#  '60+2' '63+3' '67+2' '70+2' '64+2' '75+2' '40+3' '41+2' '38+2' '39+2'
#  '72+2' '65+2' '61+2' '77+3' '44+2' '42+2' '40+2' '43+3' '37+2' '36+2'
#  '34+2' '33+2' '32+2' '35+2' '31+2' '29+2' '26+2' '30+2' '28+2' '27+2']
# 63+2    621
# 62+2    609
# 64+2    599
# 61+2    554
# 66+2    545
#        ...
# 40+3      1
# 85+2      1
# 52+4      1
# 39+3      1
# 84+2      1
# Name: cb, Length: 110, dtype: int64
# *************************
# rcb ['52+2' '53+3' '46+3' nan '49+3' '66+3' '87+3' '72+3' '57+3' '54+3' '86+3'
#  '60+3' '83+3' '50+3' '63+5' '82+3' '65+3' '51+3' '85+3' '56+3' '69+3'
#  '55+3' '85+2' '57+2' '84+3' '78+3' '44+3' '84+2' '76+3' '62+3' '67+3'
#  '73+3' '58+3' '69+2' '83+2' '79+2' '80+2' '77+2' '68+2' '80+3' '52+4'
#  '48+3' '47+3' '81+3' '79+3' '49+2' '74+3' '47+2' '54+2' '76+2' '73+2'
#  '51+2' '43+2' '53+2' '59+3' '70+3' '71+3' '39+3' '56+2' '52+3' '81+2'
#  '63+2' '46+2' '78+2' '64+3' '61+3' '45+2' '62+2' '58+2' '71+2' '75+3'
#  '68+3' '82+2' '55+2' '50+2' '48+2' '66+2' '59+2' '42+3' '74+2' '45+3'
#  '60+2' '63+3' '67+2' '70+2' '64+2' '75+2' '40+3' '41+2' '38+2' '39+2'
#  '72+2' '65+2' '61+2' '77+3' '44+2' '42+2' '40+2' '43+3' '37+2' '36+2'
#  '34+2' '33+2' '32+2' '35+2' '31+2' '29+2' '26+2' '30+2' '28+2' '27+2']
# 63+2    621
# 62+2    609
# 64+2    599
# 61+2    554
# 66+2    545
#        ...
# 40+3      1
# 85+2      1
# 52+4      1
# 39+3      1
# 84+2      1
# Name: rcb, Length: 110, dtype: int64
# *************************
# rb ['63+2' '61+3' nan '73+3' '81+3' '79+3' '66+3' '63+3' '77+3' '62+3' '84+3'
#  '76+3' '56+3' '82+3' '64+5' '58+3' '78+3' '70+3' '64+3' '74+3' '72+3'
#  '80+2' '67+2' '80+3' '60+3' '75+3' '61+2' '76+2' '67+3' '69+3' '71+2'
#  '57+3' '59+3' '75+2' '78+2' '82+2' '74+2' '79+2' '54+3' '51+3' '83+3'
#  '50+4' '49+3' '56+2' '83+2' '59+2' '62+2' '60+2' '55+2' '68+3' '55+3'
#  '64+2' '71+3' '65+2' '72+2' '51+2' '66+2' '73+2' '57+2' '77+2' '81+2'
#  '50+2' '53+2' '53+3' '70+2' '65+3' '58+2' '69+2' '54+2' '52+3' '68+2'
#  '49+2' '50+3' '48+2' '52+2' '47+2' '43+2' '46+2' '47+3' '44+2' '42+2'
#  '45+2' '46+3' '41+2' '41+3' '45+3' '40+2' '38+2' '39+2' '36+2' '37+2'
#  '35+2' '32+2' '34+2' '33+2' '31+2' '30+2']
# 61+2    667
# 63+2    660
# 62+2    642
# 59+2    639
# 60+2    598
#        ...
# 45+3      1
# 64+5      1
# 46+3      1
# 50+4      1
# 83+2      1
# Name: rb, Length: 96, dtype: int64
# *************************

# %%
# Check Info:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
# Check Head:
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 3        188         87    Slovenia      Atlético Madrid       91         93
# 4        175         74     Belgium          Real Madrid       91         91
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 3   77500000    125000               GK          Right
# 4   90000000    470000           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# 1                         5          4            5       High/Low
# 2                         5          5            5    High/Medium
# 3                         3          3            1  Medium/Medium
# 4                         4          4            4    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  40                  30                     43
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
# 4                         27                        22                  11
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
# 4                    12                    6                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                    89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                     8  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
# 4  61+3  49+3  49+3  49+3  61+3

# %%
# Check Tail:
data.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  overall  potential  \
# 18273    China PR               Beijing Renhe FC       48         56
# 18274    China PR               Shanghai SIPG FC       48         56
# 18275    China PR         Hebei China Fortune FC       48         56
# 18276    China PR  Shanghai Greenland Shenhua FC       48         54
# 18277    China PR         Hebei China Fortune FC       48         51
#
#        value_eur  wage_eur player_positions preferred_foot  \
# 18273      40000      2000               CB          Right
# 18274      40000      2000               CB          Right
# 18275      40000      1000               CM          Right
# 18276      40000      1000               CM          Right
# 18277      40000      2000               CM          Right
#
#        international_reputation  weak_foot  skill_moves      work_rate  \
# 18273                         1          3            2    Medium/High
# 18274                         1          2            2  Medium/Medium
# 18275                         1          2            2     Low/Medium
# 18276                         1          2            2        Low/Low
# 18277                         1          3            2  Medium/Medium
#
#       body_type real_face  release_clause_eur player_tags team_position  \
# 18273    Normal        No             70000.0         NaN           RES
# 18274    Normal        No             72000.0         NaN           SUB
# 18275      Lean        No             70000.0         NaN           SUB
# 18276      Lean        No             70000.0         NaN           SUB
# 18277    Normal        No                 NaN         NaN           SUB
#
#        team_jersey_number      loaned_from      joined  contract_valid_until  \
# 18273                36.0              NaN  2018-07-13                2019.0
# 18274                31.0              NaN  2019-02-01                2022.0
# 18275                38.0              NaN  2019-01-01                2019.0
# 18276                33.0              NaN  2019-02-01                2022.0
# 18277                37.0  Tianjin TEDA FC         NaN                2019.0
#
#       nation_position  nation_jersey_number  pace  shooting  passing  \
# 18273             NaN                   NaN  57.0      23.0     28.0
# 18274             NaN                   NaN  58.0      24.0     33.0
# 18275             NaN                   NaN  54.0      35.0     44.0
# 18276             NaN                   NaN  59.0      35.0     47.0
# 18277             NaN                   NaN  60.0      32.0     51.0
#
#        dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 18273       33.0       47.0    51.0        NaN          NaN         NaN
# 18274       35.0       48.0    48.0        NaN          NaN         NaN
# 18275       45.0       48.0    51.0        NaN          NaN         NaN
# 18276       47.0       45.0    52.0        NaN          NaN         NaN
# 18277       45.0       47.0    55.0        NaN          NaN         NaN
#
#        gk_reflexes  gk_speed  gk_positioning player_traits  \
# 18273          NaN       NaN             NaN           NaN
# 18274          NaN       NaN             NaN           NaN
# 18275          NaN       NaN             NaN           NaN
# 18276          NaN       NaN             NaN           NaN
# 18277          NaN       NaN             NaN           NaN
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 18273                  21                   17                          40
# 18274                  24                   20                          42
# 18275                  32                   33                          49
# 18276                  39                   34                          47
# 18277                  44                   30                          48
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 18273                       35                 27               24
# 18274                       43                 28               32
# 18275                       53                 32               40
# 18276                       54                 28               42
# 18277                       58                 25               40
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 18273           23                 21                  28                  35
# 18274           24                 29                  39                  31
# 18275           32                 32                  55                  49
# 18276           37                 39                  48                  49
# 18277           34                 35                  52                  46
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 18273                     56                     58                45
# 18274                     55                     61                43
# 18275                     55                     54                52
# 18276                     55                     63                55
# 18277                     54                     64                52
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 18273                  40                73                36             70
# 18274                  41                76                33             72
# 18275                  52                57                48             60
# 18276                  54                59                46             61
# 18277                  49                71                41             64
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 18273             60              47                16                    46
# 18274             55              44                20                    42
# 18275             50              51                26                    50
# 18276             42              55                28                    57
# 18277             40              61                30                    54
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 18273                       48                     28                25
# 18274                       49                     23                25
# 18275                       45                     38                38
# 18276                       49                     31                48
# 18277                       47                     29                52
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 18273                   39                   41                 45
# 18274                   37                   35                 42
# 18275                   36                   39                 46
# 18276                   36                   40                 39
# 18277                   38                   42                 52
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 18273                         50                        52
# 18274                         53                        57
# 18275                         52                        46
# 18276                         44                        54
# 18277                         42                        48
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 18273                   5                     5                   13
# 18274                  13                     6                   14
# 18275                   7                     8                   10
# 18276                  14                     9                   13
# 18277                   8                    12                   14
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 18273                        5                    14  32+2  32+2  32+2  31+2
# 18274                       11                     9  33+2  33+2  33+2  33+2
# 18275                        6                    14  43+2  43+2  43+2  43+2
# 18276                       13                    13  43+2  43+2  43+2  45+2
# 18277                        9                    10  42+2  42+2  42+2  44+2
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 18273  31+2  31+2  31+2  31+2  31+2  31+2  31+2  33+2  33+2  33+2  33+2  33+2
# 18274  32+2  32+2  32+2  33+2  33+2  33+2  33+2  35+2  36+2  36+2  36+2  35+2
# 18275  43+2  43+2  43+2  43+2  44+2  44+2  44+2  45+2  46+2  46+2  46+2  45+2
# 18276  44+2  44+2  44+2  45+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
# 18277  43+2  43+2  43+2  44+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 18273  43+2  42+2  42+2  42+2  43+2  45+2  46+2  46+2  46+2  45+2
# 18274  44+2  43+2  43+2  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  47+2  49+2  49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  49+2  49+2  49+2  48+2  48+2  50+2  50+2  50+2  48+2

# %%
# Check columns:
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
# Check Statistical report for numerical data
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# std        6.139669  5.585481e+06   21351.714095                  0.378861
# min       49.000000  0.000000e+00       0.000000                  1.000000
# 25%       67.000000  3.250000e+05    1000.000000                  1.000000
# 50%       71.000000  7.000000e+05    3000.000000                  1.000000
# 75%       75.000000  2.100000e+06    8000.000000                  1.000000
# max       95.000000  1.055000e+08  565000.000000                  5.000000
#
#           weak_foot   skill_moves  release_clause_eur  team_jersey_number  \
# count  18278.000000  18278.000000        1.698000e+04        18038.000000
# mean       2.944250      2.368038        4.740717e+06           20.103892
# std        0.664656      0.765038        1.103002e+07           16.603639
# min        1.000000      1.000000        1.300000e+04            1.000000
# 25%        3.000000      2.000000        5.630000e+05            9.000000
# 50%        3.000000      2.000000        1.200000e+06           17.000000
# 75%        3.000000      3.000000        3.700000e+06           27.000000
# max        5.000000      5.000000        1.958000e+08           99.000000
#
#        contract_valid_until  nation_jersey_number          pace      shooting  \
# count          18038.000000           1126.000000  16242.000000  16242.000000
# mean            2021.114591             12.114565     67.700899     52.298301
# std                1.289888              6.735922     11.297656     14.029418
# min             2019.000000              1.000000     24.000000     15.000000
# 25%             2020.000000              6.000000     61.000000     42.000000
# 50%             2021.000000             12.000000     69.000000     54.000000
# 75%             2022.000000             18.000000     75.000000     63.000000
# max             2026.000000             30.000000     96.000000     93.000000
#
#             passing     dribbling     defending        physic    gk_diving  \
# count  16242.000000  16242.000000  16242.000000  16242.000000  2036.000000
# mean      57.233777     62.531585     51.553503     64.876678    65.422397
# std       10.407844     10.284950     16.419528      9.760162     7.736278
# min       24.000000     23.000000     15.000000     27.000000    44.000000
# 25%       50.000000     57.000000     36.000000     59.000000    60.000000
# 50%       58.000000     64.000000     56.000000     66.000000    65.000000
# 75%       64.000000     69.000000     65.000000     72.000000    70.000000
# max       92.000000     96.000000     90.000000     90.000000    90.000000
#
#        gk_handling   gk_kicking  gk_reflexes     gk_speed  gk_positioning  \
# count  2036.000000  2036.000000  2036.000000  2036.000000     2036.000000
# mean     63.146365    61.832515    66.390472    37.798625       63.374754
# std       7.244023     7.510709     8.154062    10.634038        8.447876
# min      42.000000    35.000000    45.000000    12.000000       41.000000
# 25%      58.000000    57.000000    60.750000    29.000000       58.000000
# 50%      63.000000    61.000000    66.000000    39.000000       64.000000
# 75%      68.000000    66.000000    72.000000    46.000000       69.000000
# max      92.000000    93.000000    92.000000    65.000000       91.000000
#
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# count        18278.000000         18278.000000                18278.000000
# mean            49.718405            45.590218                   52.221468
# std             18.325403            19.594609                   17.428429
# min              5.000000             2.000000                    5.000000
# 25%             38.000000            30.000000                   44.000000
# 50%             54.000000            49.000000                   56.000000
# 75%             64.000000            62.000000                   64.000000
# max             93.000000            95.000000                   93.000000
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# count             18278.000000       18278.000000     18278.000000
# mean                 58.748003          42.809388        55.596509
# std                  14.679653          17.701815        18.929118
# min                   7.000000           3.000000         4.000000
# 25%                  54.000000          30.000000        50.000000
# 50%                  62.000000          44.000000        61.000000
# 75%                  68.000000          56.000000        68.000000
# max                  92.000000          90.000000        97.000000
#
#         skill_curve  skill_fk_accuracy  skill_long_passing  \
# count  18278.000000       18278.000000        18278.000000
# mean      47.325692          42.708885           52.768848
# std       18.422991          17.433612           15.246454
# min        6.000000           4.000000            8.000000
# 25%       34.000000          31.000000           43.000000
# 50%       49.000000          41.000000           56.000000
# 75%       62.000000          56.000000           64.000000
# max       94.000000          94.000000           92.000000
#
#        skill_ball_control  movement_acceleration  movement_sprint_speed  \
# count        18278.000000           18278.000000           18278.000000
# mean            58.461976              64.299923              64.415746
# std             16.741878              15.042232              14.847763
# min              5.000000              12.000000              11.000000
# 25%             54.000000              56.000000              57.000000
# 50%             63.000000              67.000000              67.000000
# 75%             69.000000              75.000000              75.000000
# max             96.000000              97.000000              96.000000
#
#        movement_agility  movement_reactions  movement_balance  \
# count      18278.000000        18278.000000      18278.000000
# mean          63.504924           61.752544         63.856439
# std           14.808380            9.135613         14.201559
# min           11.000000           21.000000         12.000000
# 25%           55.000000           56.000000         56.000000
# 50%           66.000000           62.000000         66.000000
# 75%           74.000000           68.000000         74.000000
# max           96.000000           96.000000         97.000000
#
#        power_shot_power  power_jumping  power_stamina  power_strength  \
# count      18278.000000   18278.000000   18278.000000    18278.000000
# mean          58.181694      64.928165      62.889485       65.234763
# std           13.326083      11.934059      16.017954       12.534811
# min           14.000000      19.000000      12.000000       20.000000
# 25%           48.000000      58.000000      56.000000       58.000000
# 50%           59.000000      66.000000      66.000000       66.000000
# 75%           68.000000      73.000000      74.000000       74.000000
# max           95.000000      95.000000      97.000000       97.000000
#
#        power_long_shots  mentality_aggression  mentality_interceptions  \
# count      18278.000000          18278.000000             18278.000000
# mean          46.812945             55.742149                46.380239
# std           19.322343             17.318157                20.775812
# min            4.000000              9.000000                 3.000000
# 25%           32.000000             44.000000                25.000000
# 50%           51.000000             58.000000                52.000000
# 75%           62.000000             69.000000                64.000000
# max           94.000000             95.000000                92.000000
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# count           18278.000000      18278.000000         18278.000000
# mean               50.072163         53.609749            48.383357
# std                19.594022         13.955626            15.708099
# min                 2.000000          9.000000             7.000000
# 25%                39.000000         44.000000            39.000000
# 50%                55.000000         55.000000            49.000000
# 75%                64.000000         64.000000            60.000000
# max                95.000000         94.000000            92.000000
#
#        mentality_composure  defending_marking  defending_standing_tackle  \
# count         18278.000000       18278.000000               18278.000000
# mean             58.528778          46.848889                  47.640333
# std              11.880840          20.091287                  21.585641
# min              12.000000           1.000000                   5.000000
# 25%              51.000000          29.000000                  27.000000
# 50%              60.000000          52.000000                  55.000000
# 75%              67.000000          64.000000                  66.000000
# max              96.000000          94.000000                  92.000000
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# count              18278.000000        18278.000000          18278.000000
# mean                  45.606631           16.572765             16.354853
# std                   21.217734           17.738069             16.996925
# min                    3.000000            1.000000              1.000000
# 25%                   24.000000            8.000000              8.000000
# 50%                   52.000000           11.000000             11.000000
# 75%                   64.000000           14.000000             14.000000
# max                   90.000000           90.000000             92.000000
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes
# count         18278.000000             18278.000000          18278.000000
# mean             16.212934                16.368038             16.709924
# std              16.613665                17.136497             18.038125
# min               1.000000                 1.000000              1.000000
# 25%               8.000000                 8.000000              8.000000
# 50%              11.000000                11.000000             11.000000
# 75%              14.000000                14.000000             14.000000
# max              93.000000                91.000000             92.000000

# %%
# Check Statistical report for categorical data
data.describe(include="O")
# Out:
#                                                player_url    short_name  \
# count                                               18278         18278
# unique                                              18278         17354
# top     https://sofifa.com/player/158023/lionel-messi/...  J. Rodríguez
# freq                                                    1            11
#
#          long_name         dob nationality          club player_positions  \
# count        18278       18278       18278         18278            18278
# unique       18218        6142         162           698              643
# top     Liam Kelly  1992-02-29     England  FC Barcelona               CB
# freq             3         113        1667            33             2322
#
#        preferred_foot      work_rate body_type real_face player_tags  \
# count           18278          18278     18278     18278        1499
# unique              2              9        10         2          83
# top             Right  Medium/Medium    Normal        No   #Strength
# freq            13960           9875     10750     16310         514
#
#        team_position loaned_from      joined nation_position  player_traits  \
# count          18038        1048       16990            1126           7566
# unique            29         316        1760              26            921
# top              SUB    Sassuolo  2019-07-01             SUB  Early Crosser
# freq            7820          17        1465             587            501
#
#            ls     st     rs     lw     lf     cf     rf     rw    lam    cam  \
# count   16242  16242  16242  16242  16242  16242  16242  16242  16242  16242
# unique     94     94     94    107    103    103    103    107    103    103
# top      61+2   61+2   61+2   63+2   63+2   63+2   63+2   63+2   61+2   61+2
# freq      725    725    725    736    727    727    727    736    748    748
#
#           ram     lm    lcm     cm    rcm     rm    lwb    ldm    cdm    rdm  \
# count   16242  16242  16242  16242  16242  16242  16242  16242  16242  16242
# unique    103    100     88     88     88    100     98     98     98     98
# top      61+2   61+2   58+2   58+2   58+2   61+2   59+2   59+2   59+2   59+2
# freq      748    809    775    775    775    809    682    636    636    636
#
#           rwb     lb    lcb     cb    rcb     rb
# count   16242  16242  16242  16242  16242  16242
# unique     98     96    110    110    110     96
# top      59+2   61+2   63+2   63+2   63+2   61+2
# freq      682    667    621    621    621    667

# %%
# Get all the columns which contains numerical data

num_col = data.select_dtypes(include=["int64","float64"])
print(num_col.columns)
print(num_col.shape)
# Out:
# Index(['sofifa_id', 'age', 'height_cm', 'weight_kg', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'international_reputation', 'weak_foot',
#        'skill_moves', 'release_clause_eur', 'team_jersey_number',
#        'contract_valid_until', 'nation_jersey_number', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes'],
#       dtype='object')
# (18278, 61)

# %%
# Get all the columns which contains categorical data:

cat_col = data.select_dtypes(include=["object"])
print(cat_col.columns)
print(cat_col.shape)
# Out:
# Index(['player_url', 'short_name', 'long_name', 'dob', 'nationality', 'club',
#        'player_positions', 'preferred_foot', 'work_rate', 'body_type',
#        'real_face', 'player_tags', 'team_position', 'loaned_from', 'joined',
#        'nation_position', 'player_traits', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
#        'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb',
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object')
# (18278, 43)

# %%
# remove the columns which are not appropriate to goal keepers for analyzation

data.drop(['player_url', 'sofifa_id', 'long_name', 'loaned_from', 'nation_jersey_number',
'player_tags', 'nation_position', 'player_positions','goalkeeping_diving', 'goalkeeping_handling',
'goalkeeping_kicking', 'goalkeeping_positioning'], axis=1 ,inplace=True)

# %%
data.head()
# Out:
#           short_name  age         dob  height_cm  weight_kg nationality  \
# 0           L. Messi   32  1987-06-24        170         72   Argentina
# 1  Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# 2          Neymar Jr   27  1992-02-05        175         68      Brazil
# 3           J. Oblak   26  1993-01-07        188         87    Slovenia
# 4          E. Hazard   28  1991-01-07        175         74     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 3      Atlético Madrid       91         93   77500000    125000
# 4          Real Madrid       91         91   90000000    470000
#
#   preferred_foot  international_reputation  weak_foot  skill_moves  \
# 0           Left                         5          4            4
# 1          Right                         5          4            5
# 2          Right                         5          5            5
# 3          Right                         3          3            1
# 4          Right                         4          4            4
#
#        work_rate   body_type real_face  release_clause_eur team_position  \
# 0     Medium/Low       Messi       Yes         195800000.0            RW
# 1       High/Low  C. Ronaldo       Yes          96500000.0            LW
# 2    High/Medium      Neymar       Yes         195200000.0           CAM
# 3  Medium/Medium      Normal       Yes         164700000.0            GK
# 4    High/Medium      Normal       Yes         184500000.0            LW
#
#    team_jersey_number      joined  contract_valid_until  pace  shooting  \
# 0                10.0  2004-07-01                2021.0  87.0      92.0
# 1                 7.0  2018-07-10                2022.0  90.0      93.0
# 2                10.0  2017-08-03                2022.0  91.0      85.0
# 3                13.0  2014-07-16                2023.0   NaN       NaN
# 4                 7.0  2019-07-01                2024.0  91.0      83.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     92.0       96.0       39.0    66.0        NaN          NaN         NaN
# 1     82.0       89.0       35.0    78.0        NaN          NaN         NaN
# 2     87.0       95.0       32.0    58.0        NaN          NaN         NaN
# 3      NaN        NaN        NaN     NaN       87.0         92.0        78.0
# 4     86.0       94.0       35.0    66.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3         89.0      52.0            90.0
# 4          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  40                  30                     43
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_reflexes  \
# 0                         37                        26                     8
# 1                         32                        24                    11
# 2                         26                        29                    11
# 3                         12                        18                    89
# 4                         27                        22                     8
#
#      ls    st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm  \
# 0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2
# 1  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3
# 2  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3
#
#     lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 0  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2
# 1  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3
# 2  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3
#
#     rcb    rb
# 0  52+2  63+2
# 1  53+3  61+3
# 2  46+3  61+3
# 3   NaN   NaN
# 4  49+3  61+3

# %% [markdown]
# ### Insights:
# * It might be best to remove the **player_positions** column, as it contains multiple tags for each player, creating potential ambiguity. However, let's keep the **team_positions** column, since it has only one tag for each player, offering a clearer categorization.

# %%
# Check Null Vales:
# show all the null values with max number in descending Order.

null_counts = data.isnull().sum()
null_columns = null_counts[null_counts>0].sort_values(ascending=False)
print(null_columns)
# Out:
# gk_handling             16242
# gk_kicking              16242
# gk_positioning          16242
# gk_speed                16242
# gk_diving               16242
# gk_reflexes             16242
# player_traits           10712
# ram                      2036
# lm                       2036
# lcm                      2036
# cm                       2036
# rcm                      2036
# rm                       2036
# lf                       2036
# lam                      2036
# lwb                      2036
# ldm                      2036
# cdm                      2036
# rdm                      2036
# rwb                      2036
# lb                       2036
# lcb                      2036
# cb                       2036
# rcb                      2036
# cam                      2036
# rb                       2036
# rw                       2036
# physic                   2036
# pace                     2036
# shooting                 2036
# passing                  2036
# dribbling                2036
# rf                       2036
# defending                2036
# ls                       2036
# st                       2036
# rs                       2036
# lw                       2036
# cf                       2036
# release_clause_eur       1298
# joined                   1288
# team_position             240
# contract_valid_until      240
# team_jersey_number        240
# dtype: int64

# %%
# Show the count of players based on their Natinality

data["nationality"].value_counts().head(10)
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %% [markdown]
# # 5. EDA:
# # 5.1. Univariate:

# %%
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\pooja\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (3.7.0)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (6.4.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (1.10.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\pooja\anaconda3\lib\site-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pooja\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pooja\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7)
# Requirement already satisfied: colorama in c:\users\pooja\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\pooja\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# WARNING: There was an error checking the latest version of pip.

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 1. Printing the number of player according to their height in cm.

# %%
# Printing the number of players based on their height in cm.

data["height_cm"].value_counts()
# Out:
# 180    1468
# 178    1213
# 185    1193
# 183    1160
# 175     990
# 188     904
# 182     833
# 184     820
# 186     774
# 177     722
# 181     704
# 187     682
# 176     669
# 179     641
# 190     585
# 173     567
# 174     483
# 191     464
# 170     455
# 189     439
# 172     412
# 193     316
# 192     290
# 171     262
# 168     195
# 194     173
# 169     149
# 196     139
# 195     136
# 167     102
# 165      68
# 166      60
# 197      51
# 198      35
# 163      29
# 164      21
# 199      14
# 162      12
# 201      11
# 200      10
# 203       6
# 161       5
# 202       4
# 158       3
# 160       3
# 159       3
# 157       1
# 156       1
# 205       1
# Name: height_cm, dtype: int64

# %%
# display the graph of players based on their height in cm.

plt.figure(figsize=(15,15))
sns.distplot(data["height_cm"], kde=True, bins=20)
plt.title('Height of Distribution', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Height of Distribution')

# %% [markdown]
# ### Insights:
#
# * Most players have a height ranging between 175 and 185 centimeters.

# %% [markdown]
# ### 2. Display the number of players based on their weight in kg.

# %%
data['weight_kg'].value_counts()
# Out:
# 70     1455
# 75     1410
# 80     1060
# 78     1005
# 72      983
# 73      948
# 74      890
# 77      880
# 76      860
# 68      707
# 79      659
# 71      612
# 82      584
# 83      532
# 69      524
# 81      516
# 65      488
# 67      473
# 84      454
# 85      445
# 66      366
# 64      297
# 86      296
# 88      255
# 87      230
# 63      207
# 90      169
# 62      157
# 60      142
# 89      135
# 61       81
# 92       81
# 91       74
# 93       54
# 94       42
# 59       36
# 58       35
# 95       29
# 96       21
# 57       15
# 56       13
# 97       12
# 98       10
# 55        6
# 54        6
# 101       4
# 103       3
# 99        3
# 102       3
# 100       2
# 52        2
# 104       2
# 53        2
# 107       1
# 110       1
# 50        1
# Name: weight_kg, dtype: int64

# %%
# display the graph of players based on their weight in kg.

plt.figure(figsize=(15,15))
sns.distplot(data["weight_kg"], kde=True, bins=20)
plt.title('Weight Distribution', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Weight Distribution')

# %% [markdown]
# #### Insights
#
# * Most players have a weight between 70 and 80 kilograms.

# %% [markdown]
# ### 3. Display the number of players based on their Age.

# %%
data['age'].value_counts()
# Out:
# 22    1446
# 21    1375
# 23    1358
# 27    1324
# 25    1319
# 24    1296
# 26    1270
# 20    1247
# 28    1086
# 19    1011
# 29     999
# 30     883
# 31     807
# 18     640
# 32     597
# 33     475
# 35     310
# 34     301
# 17     229
# 36     131
# 37      81
# 38      42
# 39      20
# 40      13
# 16      12
# 41       4
# 42       2
# Name: age, dtype: int64

# %%
# display the graph of players based on their age.

plt.figure(figsize=(15,15))
sns.distplot(data["age"], kde=True, bins=20)
plt.title('Age Distribution', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# ###  Player count according to their Age:

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data , x='age', palette='bright')
plt.title('Count of Players on basis of Agevin FIFA 20', fontsize=22)
plt.xlabel('Player Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Insights:
#
# * Most players are between 20 and 27 years old, with an average age of about 25.
# * The full age range extends from a minimum of 16 years to a maximum of 42 years.

# %% [markdown]
# ### 4. Display number of players according to their Nationality.
#
# Show the list of Top 10 Countries which has most number of players. Then analyse which country produces most football players in this level?

# %%
Top_10_Countries = data["nationality"].value_counts().head(10)
Top_10_Countries
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pooja\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pooja\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\pooja\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
# Plot the bar chart
plt.figure(figsize=(10, 6))
ax=Top_10_Countries.plot(kind='bar', color='skyblue')
plt.title('Top 10 Nationalities of Players')
plt.xlabel('Nationality')
plt.ylabel('Number of Players')
plt.show()

# %% [markdown]
# #### Insights:
#
# * Most numbers of players in FIFA 20 are from England, it contributes 10% of the entire dataset. The next are Germany in 2nd position and Spain in 3rd position. Top10 Countries with the number of players are listed below:
#
# 1. England -- 1667
# 2. Germany -- 1216
# 3. Spain -- 1035
# 4. France -- 984
# 5. Argentina -- 886
# 6. Brazil -- 824
# 7. Italy -- 732
# 8. Colombia -- 591
# 9. Japan -- 453
# 10. Netherlands -- 416

# %% [markdown]
# #### 5. Display the foot count of the Players:

# %%
data['preferred_foot'].value_counts()
# Out:
# Right    13960
# Left      4318
# Name: preferred_foot, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data , x='preferred_foot', palette='bright')
plt.title('Number of Players with Left vs Right preferred foot', fontsize=25)
plt.xlabel('preferred_foot', fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.show()

# %% [markdown]
# #### Insights:
#
# * The majority of players are right-footed, with approximately 76% preferring their right foot. The remaining 24% prefer their left foot.

# %%
# Analysing goal keepers data.

data['team_position'].isnull().sum()
# Out:
# 240

# %%
# Handling Null Values.

data['team_position'].fillna(data['team_position'].mode()[0],inplace=True)
data.head()
# Out:
#           short_name  age         dob  height_cm  weight_kg nationality  \
# 0           L. Messi   32  1987-06-24        170         72   Argentina
# 1  Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# 2          Neymar Jr   27  1992-02-05        175         68      Brazil
# 3           J. Oblak   26  1993-01-07        188         87    Slovenia
# 4          E. Hazard   28  1991-01-07        175         74     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 3      Atlético Madrid       91         93   77500000    125000
# 4          Real Madrid       91         91   90000000    470000
#
#   preferred_foot  international_reputation  weak_foot  skill_moves  \
# 0           Left                         5          4            4
# 1          Right                         5          4            5
# 2          Right                         5          5            5
# 3          Right                         3          3            1
# 4          Right                         4          4            4
#
#        work_rate   body_type real_face  release_clause_eur team_position  \
# 0     Medium/Low       Messi       Yes         195800000.0            RW
# 1       High/Low  C. Ronaldo       Yes          96500000.0            LW
# 2    High/Medium      Neymar       Yes         195200000.0           CAM
# 3  Medium/Medium      Normal       Yes         164700000.0            GK
# 4    High/Medium      Normal       Yes         184500000.0            LW
#
#    team_jersey_number      joined  contract_valid_until  pace  shooting  \
# 0                10.0  2004-07-01                2021.0  87.0      92.0
# 1                 7.0  2018-07-10                2022.0  90.0      93.0
# 2                10.0  2017-08-03                2022.0  91.0      85.0
# 3                13.0  2014-07-16                2023.0   NaN       NaN
# 4                 7.0  2019-07-01                2024.0  91.0      83.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     92.0       96.0       39.0    66.0        NaN          NaN         NaN
# 1     82.0       89.0       35.0    78.0        NaN          NaN         NaN
# 2     87.0       95.0       32.0    58.0        NaN          NaN         NaN
# 3      NaN        NaN        NaN     NaN       87.0         92.0        78.0
# 4     86.0       94.0       35.0    66.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3         89.0      52.0            90.0
# 4          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  40                  30                     43
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_reflexes  \
# 0                         37                        26                     8
# 1                         32                        24                    11
# 2                         26                        29                    11
# 3                         12                        18                    89
# 4                         27                        22                     8
#
#      ls    st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm  \
# 0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2
# 1  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3
# 2  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3
#
#     lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 0  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2
# 1  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3
# 2  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3
#
#     rcb    rb
# 0  52+2  63+2
# 1  53+3  61+3
# 2  46+3  61+3
# 3   NaN   NaN
# 4  49+3  61+3

# %%
# checking for null values in "Team position" column.

data["team_position"].isnull().sum()
# Out:
# 0

# %%
# Get the data of the players who's team position column value is "GK", For goalkeepers 

data_gk = data.loc[data['team_position'] == "GK"]
data_gk.head()
# Out:
#        short_name  age         dob  height_cm  weight_kg nationality  \
# 3        J. Oblak   26  1993-01-07        188         87    Slovenia
# 6   M. ter Stegen   27  1992-04-30        187         85     Germany
# 13        Alisson   26  1992-10-02        191         91      Brazil
# 14         De Gea   28  1990-11-07        192         82       Spain
# 25        Ederson   25  1993-08-17        188         86      Brazil
#
#                  club  overall  potential  value_eur  wage_eur preferred_foot  \
# 3     Atlético Madrid       91         93   77500000    125000          Right
# 6        FC Barcelona       90         93   67500000    250000          Right
# 13          Liverpool       89         91   58000000    155000          Right
# 14  Manchester United       89         90   56000000    205000          Right
# 25    Manchester City       88         91   54500000    185000           Left
#
#     international_reputation  weak_foot  skill_moves      work_rate body_type  \
# 3                          3          3            1  Medium/Medium    Normal
# 6                          3          4            1  Medium/Medium    Normal
# 13                         3          3            1  Medium/Medium    Normal
# 14                         4          3            1  Medium/Medium      Lean
# 25                         2          3            1  Medium/Medium    Normal
#
#    real_face  release_clause_eur team_position  team_jersey_number  \
# 3        Yes         164700000.0            GK                13.0
# 6        Yes         143400000.0            GK                 1.0
# 13       Yes         111700000.0            GK                 1.0
# 14       Yes         110600000.0            GK                 1.0
# 25       Yes         104900000.0            GK                31.0
#
#         joined  contract_valid_until  pace  shooting  passing  dribbling  \
# 3   2014-07-16                2023.0   NaN       NaN      NaN        NaN
# 6   2014-07-01                2022.0   NaN       NaN      NaN        NaN
# 13  2018-07-19                2024.0   NaN       NaN      NaN        NaN
# 14  2011-07-01                2020.0   NaN       NaN      NaN        NaN
# 25  2017-07-01                2024.0   NaN       NaN      NaN        NaN
#
#     defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 3         NaN     NaN       87.0         92.0        78.0         89.0
# 6         NaN     NaN       88.0         85.0        88.0         90.0
# 13        NaN     NaN       85.0         84.0        85.0         89.0
# 14        NaN     NaN       90.0         84.0        81.0         92.0
# 25        NaN     NaN       86.0         82.0        93.0         88.0
#
#     gk_speed  gk_positioning                                   player_traits  \
# 3       52.0            90.0                      Flair, Acrobatic Clearance
# 6       45.0            88.0  Swerve Pass, Acrobatic Clearance, Flair Passes
# 13      51.0            90.0                              Flair, Swerve Pass
# 14      58.0            85.0                Flair, Second Wind, Flair Passes
# 25      63.0            86.0    Leadership, Swerve Pass, Acrobatic Clearance
#
#     attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 3                   13                   11                          15
# 6                   18                   14                          11
# 13                  17                   13                          19
# 14                  17                   13                          21
# 25                  20                   14                          14
#
#     attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 3                        43                 13               12           13
# 6                        61                 14               21           18
# 13                       45                 20               27           19
# 14                       50                 13               18           21
# 25                       56                 18               23           15
#
#     skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 3                  14                  40                  30
# 6                  12                  63                  30
# 13                 18                  44                  30
# 14                 19                  47                  38
# 25                 20                  58                  40
#
#     movement_acceleration  movement_sprint_speed  movement_agility  \
# 3                      43                     60                67
# 6                      38                     50                37
# 13                     56                     47                40
# 14                     57                     58                63
# 25                     64                     63                60
#
#     movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 3                   88                49                59             78
# 6                   86                43                66             79
# 13                  88                37                64             52
# 14                  87                43                61             67
# 25                  87                48                70             66
#
#     power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 3              41              78                12                    34
# 6              35              78                10                    43
# 13             32              78                14                    27
# 14             43              60                12                    38
# 25             41              68                18                    38
#
#     mentality_interceptions  mentality_positioning  mentality_vision  \
# 3                        19                     11                65
# 6                        22                     11                70
# 13                       11                     13                66
# 14                       30                     12                65
# 25                       27                     20                70
#
#     mentality_penalties  mentality_composure  defending_marking  \
# 3                    11                   68                 27
# 6                    25                   70                 25
# 13                   23                   65                 15
# 14                   29                   68                 25
# 25                   17                   70                 29
#
#     defending_standing_tackle  defending_sliding_tackle  goalkeeping_reflexes  \
# 3                          12                        18                    89
# 6                          13                        10                    90
# 13                         19                        16                    89
# 14                         21                        13                    92
# 25                         15                         8                    88
#
#      ls   st   rs   lw   lf   cf   rf   rw  lam  cam  ram   lm  lcm   cm  rcm  \
# 3   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      rm  lwb  ldm  cdm  rdm  rwb   lb  lcb   cb  rcb   rb
# 3   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# get the data of the players who are not goalkeepers

data_others = data.loc[data["team_position"] != "GK"]
data_others.head()
# Out:
#           short_name  age         dob  height_cm  weight_kg nationality  \
# 0           L. Messi   32  1987-06-24        170         72   Argentina
# 1  Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# 2          Neymar Jr   27  1992-02-05        175         68      Brazil
# 4          E. Hazard   28  1991-01-07        175         74     Belgium
# 5       K. De Bruyne   28  1991-06-28        181         70     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 4          Real Madrid       91         91   90000000    470000
# 5      Manchester City       91         91   90000000    370000
#
#   preferred_foot  international_reputation  weak_foot  skill_moves  \
# 0           Left                         5          4            4
# 1          Right                         5          4            5
# 2          Right                         5          5            5
# 4          Right                         4          4            4
# 5          Right                         4          5            4
#
#      work_rate   body_type real_face  release_clause_eur team_position  \
# 0   Medium/Low       Messi       Yes         195800000.0            RW
# 1     High/Low  C. Ronaldo       Yes          96500000.0            LW
# 2  High/Medium      Neymar       Yes         195200000.0           CAM
# 4  High/Medium      Normal       Yes         184500000.0            LW
# 5    High/High      Normal       Yes         166500000.0           RCM
#
#    team_jersey_number      joined  contract_valid_until  pace  shooting  \
# 0                10.0  2004-07-01                2021.0  87.0      92.0
# 1                 7.0  2018-07-10                2022.0  90.0      93.0
# 2                10.0  2017-08-03                2022.0  91.0      85.0
# 4                 7.0  2019-07-01                2024.0  91.0      83.0
# 5                17.0  2015-08-30                2023.0  76.0      86.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     92.0       96.0       39.0    66.0        NaN          NaN         NaN
# 1     82.0       89.0       35.0    78.0        NaN          NaN         NaN
# 2     87.0       95.0       32.0    58.0        NaN          NaN         NaN
# 4     86.0       94.0       35.0    66.0        NaN          NaN         NaN
# 5     92.0       86.0       61.0    78.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 4          NaN       NaN             NaN
# 5          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
# 5  Power Free-Kick, Avoids Using Weaker Foot, Div...                  93
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 4                   84                          61                       89
# 5                   82                          55                       92
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 4                 83               95           83                 79
# 5                 82               86           85                 83
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 4                  83                  94                     94
# 5                  91                  91                     77
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 4                     88                95                  90
# 5                     76                78                  91
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 4                94                82             56             84
# 5                76                91             63             89
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 4              63                80                    54
# 5              74                90                    76
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 4                       41                     87                89
# 5                       61                     88                94
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 4                   88                   91                 34
# 5                   79                   91                 68
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_reflexes  \
# 0                         37                        26                     8
# 1                         32                        24                    11
# 2                         26                        29                    11
# 4                         27                        22                     8
# 5                         58                        51                    13
#
#      ls    st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm  \
# 0  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2
# 1  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3
# 2  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3
# 4  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3
# 5  82+3  82+3  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3
#
#     lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 0  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2
# 1  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3
# 2  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3
# 4  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3
# 5  87+3  87+3  87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3
#
#     rcb    rb
# 0  52+2  63+2
# 1  53+3  61+3
# 2  46+3  61+3
# 4  49+3  61+3
# 5  66+3  73+3

# %%
# # Fetch all the null values present in data_gk.

data_gk.columns[data.isnull().any()]
# Out:
# Index(['release_clause_eur', 'team_jersey_number', 'joined',
#        'contract_valid_until', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'ls',
#        'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm',
#        'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object')

# %%
# Show all the null values in descending order.

null_counts = data_gk.isnull().sum()
null_columns = null_counts[null_counts>0].sort_values(ascending=False)
print(null_columns)
# Out:
# lam                   662
# ldm                   662
# lm                    662
# lcm                   662
# cm                    662
# rcm                   662
# rm                    662
# lwb                   662
# cdm                   662
# cam                   662
# rdm                   662
# rwb                   662
# lb                    662
# lcb                   662
# cb                    662
# rcb                   662
# ram                   662
# rb                    662
# ls                    662
# pace                  662
# rf                    662
# cf                    662
# lf                    662
# lw                    662
# rs                    662
# st                    662
# rw                    662
# physic                662
# defending             662
# dribbling             662
# passing               662
# shooting              662
# player_traits         316
# joined                 41
# release_clause_eur     41
# dtype: int64

# %% [markdown]
# #### Insights:
#
# * Key skills for a goalkeeper encompass speed, positioning, reflexes, diving, and handling.
# * Goalkeepers generally do not require skills like pace, shooting, passing, dribbling, or defending.
# * Hence, it makes sense to remove columns that are not critical for goalkeeping and contain null values, representing about 3.6% of the dataset.

# %%
data_gk = data_gk.drop(['pace', 'shooting', 'passing', 'dribbling','player_traits','physic',
       'defending','ls','st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm',
       'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
       'lcb', 'cb', 'rcb', 'rb'], axis=1)
data_gk.head()
# Out:
#        short_name  age         dob  height_cm  weight_kg nationality  \
# 3        J. Oblak   26  1993-01-07        188         87    Slovenia
# 6   M. ter Stegen   27  1992-04-30        187         85     Germany
# 13        Alisson   26  1992-10-02        191         91      Brazil
# 14         De Gea   28  1990-11-07        192         82       Spain
# 25        Ederson   25  1993-08-17        188         86      Brazil
#
#                  club  overall  potential  value_eur  wage_eur preferred_foot  \
# 3     Atlético Madrid       91         93   77500000    125000          Right
# 6        FC Barcelona       90         93   67500000    250000          Right
# 13          Liverpool       89         91   58000000    155000          Right
# 14  Manchester United       89         90   56000000    205000          Right
# 25    Manchester City       88         91   54500000    185000           Left
#
#     international_reputation  weak_foot  skill_moves      work_rate body_type  \
# 3                          3          3            1  Medium/Medium    Normal
# 6                          3          4            1  Medium/Medium    Normal
# 13                         3          3            1  Medium/Medium    Normal
# 14                         4          3            1  Medium/Medium      Lean
# 25                         2          3            1  Medium/Medium    Normal
#
#    real_face  release_clause_eur team_position  team_jersey_number  \
# 3        Yes         164700000.0            GK                13.0
# 6        Yes         143400000.0            GK                 1.0
# 13       Yes         111700000.0            GK                 1.0
# 14       Yes         110600000.0            GK                 1.0
# 25       Yes         104900000.0            GK                31.0
#
#         joined  contract_valid_until  gk_diving  gk_handling  gk_kicking  \
# 3   2014-07-16                2023.0       87.0         92.0        78.0
# 6   2014-07-01                2022.0       88.0         85.0        88.0
# 13  2018-07-19                2024.0       85.0         84.0        85.0
# 14  2011-07-01                2020.0       90.0         84.0        81.0
# 25  2017-07-01                2024.0       86.0         82.0        93.0
#
#     gk_reflexes  gk_speed  gk_positioning  attacking_crossing  \
# 3          89.0      52.0            90.0                  13
# 6          90.0      45.0            88.0                  18
# 13         89.0      51.0            90.0                  17
# 14         92.0      58.0            85.0                  17
# 25         88.0      63.0            86.0                  20
#
#     attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 3                    11                          15                       43
# 6                    14                          11                       61
# 13                   13                          19                       45
# 14                   13                          21                       50
# 25                   14                          14                       56
#
#     attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 3                  13               12           13                 14
# 6                  14               21           18                 12
# 13                 20               27           19                 18
# 14                 13               18           21                 19
# 25                 18               23           15                 20
#
#     skill_long_passing  skill_ball_control  movement_acceleration  \
# 3                   40                  30                     43
# 6                   63                  30                     38
# 13                  44                  30                     56
# 14                  47                  38                     57
# 25                  58                  40                     64
#
#     movement_sprint_speed  movement_agility  movement_reactions  \
# 3                      60                67                  88
# 6                      50                37                  86
# 13                     47                40                  88
# 14                     58                63                  87
# 25                     63                60                  87
#
#     movement_balance  power_shot_power  power_jumping  power_stamina  \
# 3                 49                59             78             41
# 6                 43                66             79             35
# 13                37                64             52             32
# 14                43                61             67             43
# 25                48                70             66             41
#
#     power_strength  power_long_shots  mentality_aggression  \
# 3               78                12                    34
# 6               78                10                    43
# 13              78                14                    27
# 14              60                12                    38
# 25              68                18                    38
#
#     mentality_interceptions  mentality_positioning  mentality_vision  \
# 3                        19                     11                65
# 6                        22                     11                70
# 13                       11                     13                66
# 14                       30                     12                65
# 25                       27                     20                70
#
#     mentality_penalties  mentality_composure  defending_marking  \
# 3                    11                   68                 27
# 6                    25                   70                 25
# 13                   23                   65                 15
# 14                   29                   68                 25
# 25                   17                   70                 29
#
#     defending_standing_tackle  defending_sliding_tackle  goalkeeping_reflexes
# 3                          12                        18                    89
# 6                          13                        10                    90
# 13                         19                        16                    89
# 14                         21                        13                    92
# 25                         15                         8                    88

# %%
# Check shape of data_gk:
data_gk.shape
# Out:
# (662, 59)

# %% [markdown]
# ### 6. Show the overall of the data_gk:

# %%
data_gk.overall.value_counts().head()
# Out:
# 66    52
# 67    49
# 73    44
# 68    42
# 70    42
# Name: overall, dtype: int64

# %%
# graphical representation of the column 'overall' against 'density')

sns.distplot(a =data_gk["overall"], kde=True , bins=20)
# Out:
# <Axes: xlabel='overall', ylabel='Density'>

# %% [markdown]
# ### Insights:
# * Overall value of the goal keeper lies in the range 50-90, It's mean valus is 69.

# %% [markdown]
# ### 7. Display of the wage_eur:

# %%
data_gk.wage_eur.value_counts()
# Out:
# 1000      153
# 2000      104
# 3000       73
# 4000       43
# 5000       37
#          ...
# 75000       1
# 27000       1
# 71000       1
# 67000       1
# 125000      1
# Name: wage_eur, Length: 66, dtype: int64

# %%
# Graphical Representation of the column 'wage_eur' against 'density'

sns.distplot(a = data_gk["wage_eur"], kde=True)
# Out:
# <Axes: xlabel='wage_eur', ylabel='Density'>

# %% [markdown]
# ###  Insights:
#
# * According to the graph The wage of the goal keepers is less its about 50K Euros. Players might get high wages.

# %%
# In this graph, we analyse the traits of goalkeepers i.e., diving, handling, kicking, reflexes, speed, positioning with line graph

plt.figure(figsize=(10,5))
sns.lineplot(x='potential',y='gk_diving',data=data_gk, legend='brief',ci=None).set_title('players potential with respect to gk skills')
sns.lineplot(x='potential',y= 'gk_handling' , data=data_gk,legend='brief',ci=None)
sns.lineplot(x='potential' ,y= 'gk_kicking' , data=data_gk, legend='brief',ci=None)
sns.lineplot(x='potential', y='gk_reflexes',data=data_gk, legend='brief',ci=None)
sns.lineplot(x='potential', y='gk_speed', data=data_gk, legend='brief',ci=None)
sns.lineplot(x='potential',y= 'gk_positioning',data=data_gk, legend='brief',ci=None).set_ylabel('gk_diving, gk_handling, gk_kicking , gk_positioning, gk_speed and gk_reflexes')
plt.legend(['gk_diving' , 'gk_handling', 'gk_kicking' , 'gk_reflexes', 'gk_positioning' , 'gk_speed'])
plt.show()

# %% [markdown]
# ### Insights:
#
# * More than other traits Handling and Reflexes are seen highly in goalkeepers.

# %%
# Showing all the null values which has max number in descending Order.

null_counts = data_others.isnull().sum()
null_columns = null_counts[null_counts>0].sort_values(ascending=False)
print(null_columns)
# Out:
# gk_kicking              16242
# gk_speed                16242
# gk_diving               16242
# gk_handling             16242
# gk_positioning          16242
# gk_reflexes             16242
# player_traits           10396
# ram                      1374
# lm                       1374
# lcm                      1374
# cm                       1374
# rcm                      1374
# rm                       1374
# lwb                      1374
# lf                       1374
# lam                      1374
# ldm                      1374
# cdm                      1374
# rdm                      1374
# rwb                      1374
# lb                       1374
# lcb                      1374
# cb                       1374
# rcb                      1374
# cam                      1374
# rb                       1374
# rw                       1374
# rf                       1374
# pace                     1374
# shooting                 1374
# passing                  1374
# dribbling                1374
# defending                1374
# physic                   1374
# ls                       1374
# st                       1374
# rs                       1374
# lw                       1374
# cf                       1374
# release_clause_eur       1257
# joined                   1247
# team_jersey_number        240
# contract_valid_until      240
# dtype: int64

# %%
# remove all the irrevelant columns from other players dataframe

data = data_others.drop([ 'gk_diving', 'gk_handling', 'gk_kicking',
       'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits','dob','work_rate','real_face'], axis=1)

# %%
data.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   32        170         72   Argentina
# 1  Cristiano Ronaldo   34        187         83    Portugal
# 2          Neymar Jr   27        175         68      Brazil
# 4          E. Hazard   28        175         74     Belgium
# 5       K. De Bruyne   28        181         70     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 4          Real Madrid       91         91   90000000    470000
# 5      Manchester City       91         91   90000000    370000
#
#   preferred_foot  international_reputation  weak_foot  skill_moves  \
# 0           Left                         5          4            4
# 1          Right                         5          4            5
# 2          Right                         5          5            5
# 4          Right                         4          4            4
# 5          Right                         4          5            4
#
#     body_type  release_clause_eur team_position  team_jersey_number  \
# 0       Messi         195800000.0            RW                10.0
# 1  C. Ronaldo          96500000.0            LW                 7.0
# 2      Neymar         195200000.0           CAM                10.0
# 4      Normal         184500000.0            LW                 7.0
# 5      Normal         166500000.0           RCM                17.0
#
#        joined  contract_valid_until  pace  shooting  passing  dribbling  \
# 0  2004-07-01                2021.0  87.0      92.0     92.0       96.0
# 1  2018-07-10                2022.0  90.0      93.0     82.0       89.0
# 2  2017-08-03                2022.0  91.0      85.0     87.0       95.0
# 4  2019-07-01                2024.0  91.0      83.0     86.0       94.0
# 5  2015-08-30                2023.0  76.0      86.0     92.0       86.0
#
#    defending  physic  attacking_crossing  attacking_finishing  \
# 0       39.0    66.0                  88                   95
# 1       35.0    78.0                  84                   94
# 2       32.0    58.0                  87                   87
# 4       35.0    66.0                  81                   84
# 5       61.0    78.0                  93                   82
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       92                 88
# 1                          89                       83                 87
# 2                          62                       87                 87
# 4                          61                       89                 83
# 5                          55                       92                 82
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0               97           93                 94                  92
# 1               89           81                 76                  77
# 2               96           88                 87                  81
# 4               95           83                 79                  83
# 5               86           85                 83                  91
#
#    skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                  96                     91                     84
# 1                  92                     89                     91
# 2                  95                     94                     89
# 4                  94                     94                     88
# 5                  91                     77                     76
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0                93                  95                95                86
# 1                87                  96                71                95
# 2                96                  92                84                80
# 4                95                  90                94                82
# 5                78                  91                76                91
#
#    power_jumping  power_stamina  power_strength  power_long_shots  \
# 0             68             75              68                94
# 1             95             85              78                93
# 2             61             81              49                84
# 4             56             84              63                80
# 5             63             89              74                90
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0                    48                       40                     94
# 1                    63                       29                     95
# 2                    51                       36                     87
# 4                    54                       41                     87
# 5                    76                       61                     88
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0                94                   75                   96
# 1                82                   85                   95
# 2                90                   90                   94
# 4                89                   88                   91
# 5                94                   79                   91
#
#    defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 0                 33                         37                        26
# 1                 28                         32                        24
# 2                 27                         26                        29
# 4                 34                         27                        22
# 5                 68                         58                        51
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 4                     8  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
# 5                    13  82+3  82+3  82+3  87+3  87+3  87+3  87+3  87+3  88+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
# 5  88+3  88+3  88+3  87+3  87+3  87+3  88+3  77+3  77+3  77+3  77+3  77+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 4  61+3  49+3  49+3  49+3  61+3
# 5  73+3  66+3  66+3  66+3  73+3

# %%
# handle null values of "joined and 'contract valid untill' columns using "fillna" function

data['joined'].fillna(0, inplace=True)
data[ 'contract_valid_until'].fillna(0, inplace= True)

# %%
data['contract_valid_until'] =data['contract_valid_until'].astype(int)
data['contract_valid_until'].head()
# Out:
# 0    2021
# 1    2022
# 2    2022
# 4    2024
# 5    2023
# Name: contract_valid_until, dtype: int32

# %% [markdown]
# ## 5.2 Bivariate Analysis:
#
# ### 1. Graphical Representation of the distribution of overall rating vs age of players.

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(data =data, x='age', y='overall')
# Out:
# <Axes: xlabel='age', ylabel='overall'>

# %% [markdown]
# ### Insights:
#
# * The general trend in player performance over time shows that players tend to improve steadily as they age. They usually reach their highest performance levels around age 30, then begin to decline gradually. However, there's an interesting rebound in performance around age 40. This resurgence might be due to experienced veteran players who bring significant skill and knowledge to the game. This unique pattern adds an interesting dimension to the overall narrative of player growth and performance.

# %%
plt.figure(figsize=(12, 3))
sns.lineplot(data =data, x='age', y='potential')
# Out:
# <Axes: xlabel='age', ylabel='potential'>

# %% [markdown]
# ### Insights:
#
# * Players in their 20s to early 30s generally show a steady level of performance with only slight variations. During this period, the skills and capabilities of players tend to remain fairly consistent. However, once players reach the age of 35, there's a noticeable increase in their potential, suggesting a surprising level of resilience and sustained skill in this older age group. It's worth noting, though, that this elevated potential starts to decline as players get older, leading to a clear drop in performance after 35.

# %%
# Check the head of 'wage_eur' column

data['wage_eur'].head()
# Out:
# 0    565000
# 1    405000
# 2    290000
# 4    470000
# 5    370000
# Name: wage_eur, dtype: int64

# %%
# Check the head of 'value_eur' column

data['value_eur'].head()
# Out:
# 0     95500000
# 1     58500000
# 2    105500000
# 4     90000000
# 5     90000000
# Name: value_eur, dtype: int64

# %%
# Data visualization of two columns, 'overall' and 'value_eur' with scatterplot

sns.scatterplot(data=data, x="overall", y="value_eur", color = "orange")
# Out:
# <Axes: xlabel='overall', ylabel='value_eur'>

# %%
# Check head of 'release_clause_eur' column

data['release_clause_eur'].head()
# Out:
# 0    195800000.0
# 1     96500000.0
# 2    195200000.0
# 4    184500000.0
# 5    166500000.0
# Name: release_clause_eur, dtype: float64

# %%
# Get the count of null values of the column 'release_clause_eur'

data['release_clause_eur'].isnull().sum()
# Out:
# 1257

# %%
# handling the values with 'mean' function 

data['release_clause_eur']=data['release_clause_eur'].fillna( (data['release_clause_eur'].mean()))

# %%
# converting the datatype to 'int'

data['release_clause_eur']=data['release_clause_eur'].astype(int)

# %%
# get the the columns, 'value_eur' and 'release_clause _eur' 

data_val=data.loc[:,['value_eur', 'release_clause_eur']]
data_val.head(10)
# Out:
#     value_eur  release_clause_eur
# 0    95500000           195800000
# 1    58500000            96500000
# 2   105500000           195200000
# 4    90000000           184500000
# 5    90000000           166500000
# 7    78000000           150200000
# 8    45000000            92300000
# 9    80500000           148900000
# 10   93500000           191700000
# 11   67500000           119800000

# %%
# compare the values of two columns, release_clause vs value in euro for every player using bargraph

data_val.head(10).plot(kind ='bar', figsize=(20,15))

#setting title for the graph
plt.title('comparision of release_clause vs value in euro for each player',fontsize=25)
            
#labelling x and y axis 
plt.xlabel('players', fontsize=20)
plt.ylabel('value in euros billions',fontsize=20)
# Out:
# Text(0, 0.5, 'value in euros\xa0billions')

# %% [markdown]
# * The release clause is consistently set at a higher value than the individual player's worth.

# %%
data['international_reputation'].value_counts()
# Out:
# 1    16215
# 2     1082
# 3      271
# 4       43
# 5        5
# Name: international_reputation, dtype: int64

# %%
# graphical representation of the correlation between values of 'wage leur and 'international reputation' columns using scatterplot

sns.scatterplot(data=data, x="wage_eur", y="international_reputation")
plt.show()

# %% [markdown]
# ###  Insights:
#
# * The plot offers a general overview showing that players with higher reputations usually earn larger wages. This suggests a positive correlation between these factors, implying that a rise in a player's reputation often leads to a higher salary.

# %%
# Graphical Representation of the correlation between values of 'age' columns using scatterplot

sns.scatterplot(data=data, x='age', y="wage_eur")
plt.show()

# %% [markdown]
# ### Insights:
#
# * Wages are primarily concentrated in the mid-range, with players aged 24 to 34 accounting for a significant portion of the total. As players get older, their wages tend to gradually decrease. Younger players, typically those just starting out, earn much less than their more seasoned colleagues. These trends highlight the impact of both age and experience on player compensation in the given dataset.

# %%
# The null values in the mentioned columns are filled with mean of the column

data [ 'pace' ] = data['pace'].fillna((data['pace'].mean()))
data ['shooting'] = data ['shooting'].fillna((data['shooting'].mean()))
data ['passing'] = data['passing'].fillna((data['passing'].mean()))
data ['dribbling'] = data['dribbling'].fillna((data['dribbling'].mean()))
data ['defending' ] = data['defending' ].fillna( (data['defending'].mean()))
data ['physic'] = data[ 'physic'].fillna((data['physic'].mean()))

# %%
# fetch the mentioned columns

df= data.loc[:,['short_name','defending','physic','pace','shooting','dribbling','passing']]
df.head()
# Out:
#           short_name  defending  physic  pace  shooting  dribbling  passing
# 0           L. Messi       39.0    66.0  87.0      92.0       96.0     92.0
# 1  Cristiano Ronaldo       35.0    78.0  90.0      93.0       89.0     82.0
# 2          Neymar Jr       32.0    58.0  91.0      85.0       95.0     87.0
# 4          E. Hazard       35.0    66.0  91.0      83.0       94.0     86.0
# 5       K. De Bruyne       61.0    78.0  76.0      86.0       86.0     92.0

# %%
# Checking various skills of the players.. defending, pace, shooting, passing, etc using line graph

plt.figure(figsize= (12,10))
sns.lineplot(x='potential',y='defending',data=data,legend='brief',ci=None).set_title('players potential with respect to gk skills')
sns.lineplot(x='potential',y= 'pace' , data=data,legend='brief',ci=None)
sns.lineplot(x='potential' ,y= 'shooting' , data=data, legend='brief',ci=None)
sns.lineplot(x='potential', y='passing',data=data, legend='brief',ci=None)
sns.lineplot(x='potential', y='dribbling', data=data, legend='brief',ci=None)
sns.lineplot(x='potential',y= 'physic',data=data, legend='brief',ci=None).set_ylabel('defending, pace, shooting , passing, dribbling and physic')
plt.legend(['defending' , 'pace', 'shooting' , 'passing', 'dribbling' , 'physic'])
plt.show()

# %% [markdown]
# ### Insights:
#
# Players exhibit a steady improvement in skills like dribbling, pace, and shooting, especially when their potential is above 60. However, it's notable that defensive abilities receive comparatively less attention.
#
# Additionally, given the diverse player roles denoted by the "team_position" attribute, a simplified categorization could be useful. A suggested classification might consist of these five groups:
#
# * Reserve
# * Substitute
# * Defender
# * Midfielder
# * Forward

# %%
# From 'Overall' column, fetch all the rows whose value is more than 50

x=data[data["overall"]>50]
              
# Graphical representation of 'overall' and 'wage eur' column using scatterplot

sns.scatterplot(data=data,x="overall",y="wage_eur",color="red")
plt.show()

# %% [markdown]
# ### Insights:
#
# * The player with overall > 90 gets more wage

# %%
# Graphical representation of the potential of players with more skill moves vs weak foot 

plt.figure(figsize=(10,6))
sns.lineplot(x='potential',y='skill_moves', data=data,legend='brief').set_title('player skill_moves and weak_foot') 
sns.lineplot(x='potential',y= 'weak_foot',data=data, legend= 'brief').set_ylabel('skill moves/weak foot') 
plt.legend(['skill_moves', 'weak_foot'])
plt.show()

# %% [markdown]
# ### Insights:
#
# * Stables players are the players who are more skill_movers than weak_foot

# %%
fig, ax = plt.subplots(1,3, figsize=(12, 4))
sns.lineplot(x="skill_moves", y='potential', data=data, ax=ax[0]).set(title='Skill Moves Vs Potential')
sns.lineplot(x="weak_foot", y='potential', data=data, ax=ax[1]).set(title='Weak Foot Vs Potential')
sns.lineplot(x="international_reputation", y='potential',data=data, ax=ax[2]).set(title='International Reputation Vs Potential')
plt.show()

# %% [markdown]
# ### Insights:
#
# * A high level of skill in executing Skill Moves leads to a significant boost in Potential Rating, with a distinct upward trend as the Skill Moves ability increases. Similarly, proficiency with the Weak Foot contributes positively to a player's Potential.
#
# * Additionally, there's a strong and direct correlation between high Potential and International Reputation. Players with a potential rating above 85 are more likely to achieve international acclaim, reinforcing the connection between a player's high potential and their recognition on the world stage.

# %% [markdown]
# ### 2. Who are the offensive players that gets paid the most? the striker, the right-winger or the left-winger?

# %%
# Split the Data of Strikers (ST) into the Right Wingers(RW) and Left Wingers (LW)

RW = data[data['team_position'] == 'RW']
LW = data[data['team_position'] == 'LW']
ST = data[data['team_position'] == 'ST']
offensive_list = [RW,ST,LW]
op_1 = pd.concat(offensive_list)

op_2 = op_1 [['short_name','team_position', 'wage_eur']].sort_values(by='wage_eur', ascending=False).reset_index(drop=True)
op=op_2.groupby(by='team_position', as_index=False)
op.head()
# Out:
#            short_name team_position  wage_eur
# 0            L. Messi            RW    565000
# 1           E. Hazard            LW    470000
# 2   Cristiano Ronaldo            LW    405000
# 3        A. Griezmann            LW    370000
# 4           L. Suárez            ST    355000
# 5           S. Agüero            ST    300000
# 6         R. Sterling            LW    255000
# 7            M. Salah            RW    240000
# 8      R. Lewandowski            ST    235000
# 9             S. Mané            LW    220000
# 10            H. Kane            ST    220000
# 11          P. Dybala            RW    215000
# 12     Bernardo Silva            RW    210000
# 13          E. Cavani            ST    195000
# 16          K. Mbappé            RW    155000

# %%
op.sum()
# Out:
#   team_position  wage_eur
# 0            LW   3776000
# 1            RW   3385000
# 2            ST   7535000

# %%
# Fetch the Average Wage of Offensive Players based on their Position

avg_wage_op = pd.DataFrame(op.mean())
avg_wage_op.rename(columns= {"wage_eur":"Average_wage"}, inplace=True)
avg_wage_op.index+=1
avg_wage_op
# Out:
#   team_position  Average_wage
# 1            LW  23308.641975
# 2            RW  21024.844720
# 3            ST  16451.965066

# %%
sns.barplot(data = avg_wage_op, x='team_position', y='Average_wage')
# Out:
# <Axes: xlabel='team_position', ylabel='Average_wage'>

# %% [markdown]
# ### Insights:
#
# * through this graph we learn that left wingers gets more wages than strikers and right wingerd
#
# Left wingers > strikers > Right wingers

# %%
# get all the columns.

columns = ['ls','st','rs', 'lw', 'lf','cf', 'rf', 'rw', 'lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm', 
           'cdm','rdm','rwb','lb','lcb','cb','rcb','rb']

# %%
# with split function handle the value of the columns

for col in columns:
    data[col]=data[col].str.split('+', n=1,expand = True)[0]
    data[['ls','st','rs', 'lw', 'lf','cf', 'rf', 'rw', 'lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm', 
           'cdm','rdm','rwb','lb','lcb','cb','rcb','rb']]=data[columns]
    
# handle null values

data[columns]=data[columns].fillna(0)
data.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   32        170         72   Argentina
# 1  Cristiano Ronaldo   34        187         83    Portugal
# 2          Neymar Jr   27        175         68      Brazil
# 4          E. Hazard   28        175         74     Belgium
# 5       K. De Bruyne   28        181         70     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 4          Real Madrid       91         91   90000000    470000
# 5      Manchester City       91         91   90000000    370000
#
#   preferred_foot  international_reputation  weak_foot  skill_moves  \
# 0           Left                         5          4            4
# 1          Right                         5          4            5
# 2          Right                         5          5            5
# 4          Right                         4          4            4
# 5          Right                         4          5            4
#
#     body_type  release_clause_eur team_position  team_jersey_number  \
# 0       Messi           195800000            RW                10.0
# 1  C. Ronaldo            96500000            LW                 7.0
# 2      Neymar           195200000           CAM                10.0
# 4      Normal           184500000            LW                 7.0
# 5      Normal           166500000           RCM                17.0
#
#        joined  contract_valid_until  pace  shooting  passing  dribbling  \
# 0  2004-07-01                  2021  87.0      92.0     92.0       96.0
# 1  2018-07-10                  2022  90.0      93.0     82.0       89.0
# 2  2017-08-03                  2022  91.0      85.0     87.0       95.0
# 4  2019-07-01                  2024  91.0      83.0     86.0       94.0
# 5  2015-08-30                  2023  76.0      86.0     92.0       86.0
#
#    defending  physic  attacking_crossing  attacking_finishing  \
# 0       39.0    66.0                  88                   95
# 1       35.0    78.0                  84                   94
# 2       32.0    58.0                  87                   87
# 4       35.0    66.0                  81                   84
# 5       61.0    78.0                  93                   82
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       92                 88
# 1                          89                       83                 87
# 2                          62                       87                 87
# 4                          61                       89                 83
# 5                          55                       92                 82
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0               97           93                 94                  92
# 1               89           81                 76                  77
# 2               96           88                 87                  81
# 4               95           83                 79                  83
# 5               86           85                 83                  91
#
#    skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                  96                     91                     84
# 1                  92                     89                     91
# 2                  95                     94                     89
# 4                  94                     94                     88
# 5                  91                     77                     76
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0                93                  95                95                86
# 1                87                  96                71                95
# 2                96                  92                84                80
# 4                95                  90                94                82
# 5                78                  91                76                91
#
#    power_jumping  power_stamina  power_strength  power_long_shots  \
# 0             68             75              68                94
# 1             95             85              78                93
# 2             61             81              49                84
# 4             56             84              63                80
# 5             63             89              74                90
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0                    48                       40                     94
# 1                    63                       29                     95
# 2                    51                       36                     87
# 4                    54                       41                     87
# 5                    76                       61                     88
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0                94                   75                   96
# 1                82                   85                   95
# 2                90                   90                   94
# 4                89                   88                   91
# 5                94                   79                   91
#
#    defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 0                 33                         37                        26
# 1                 28                         32                        24
# 2                 27                         26                        29
# 4                 34                         27                        22
# 5                 68                         58                        51
#
#    goalkeeping_reflexes  ls  st  rs  lw  lf  cf  rf  rw lam cam ram  lm lcm  \
# 0                     8  89  89  89  93  93  93  93  93  93  93  93  92  87
# 1                    11  91  91  91  89  90  90  90  89  88  88  88  88  81
# 2                    11  84  84  84  90  89  89  89  90  90  90  90  89  82
# 4                     8  83  83  83  89  88  88  88  89  89  89  89  89  83
# 5                    13  82  82  82  87  87  87  87  87  88  88  88  88  87
#
#    cm rcm  rm lwb ldm cdm rdm rwb  lb lcb  cb rcb  rb
# 0  87  87  92  68  66  66  66  68  63  52  52  52  63
# 1  81  81  88  65  61  61  61  65  61  53  53  53  61
# 2  82  82  89  66  61  61  61  66  61  46  46  46  61
# 4  83  83  89  66  63  63  63  66  61  49  49  49  61
# 5  87  87  88  77  77  77  77  77  73  66  66  66  73

# %% [markdown]
# # 6. Data Preprocessing:

# %% [markdown]
# ### 6.1 Null Values:

# %%
data.isnull().sum()
# Out:
# short_name     0
# age            0
# height_cm      0
# weight_kg      0
# nationality    0
#               ..
# lb             0
# lcb            0
# cb             0
# rcb            0
# rb             0
# Length: 82, dtype: int64

# %% [markdown]
# ### 6.2 Duplicated values:

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 6.3. Scaling The data:

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
lc = LabelEncoder()

# %%
data['nationality']=lc.fit_transform(data["nationality"])
data['club']=lc.fit_transform(data['club'])
data.head()
# Out:
#           short_name  age  height_cm  weight_kg  nationality  club  overall  \
# 0           L. Messi   32        170         72            5   224       94
# 1  Cristiano Ronaldo   34        187         83          120   350       93
# 2          Neymar Jr   27        175         68           18   462       92
# 4          E. Hazard   28        175         74           12   505       91
# 5       K. De Bruyne   28        181         70           12   400       91
#
#    potential  value_eur  wage_eur preferred_foot  international_reputation  \
# 0         94   95500000    565000           Left                         5
# 1         93   58500000    405000          Right                         5
# 2         92  105500000    290000          Right                         5
# 4         91   90000000    470000          Right                         4
# 5         91   90000000    370000          Right                         4
#
#    weak_foot  skill_moves   body_type  release_clause_eur team_position  \
# 0          4            4       Messi           195800000            RW
# 1          4            5  C. Ronaldo            96500000            LW
# 2          5            5      Neymar           195200000           CAM
# 4          4            4      Normal           184500000            LW
# 5          5            4      Normal           166500000           RCM
#
#    team_jersey_number      joined  contract_valid_until  pace  shooting  \
# 0                10.0  2004-07-01                  2021  87.0      92.0
# 1                 7.0  2018-07-10                  2022  90.0      93.0
# 2                10.0  2017-08-03                  2022  91.0      85.0
# 4                 7.0  2019-07-01                  2024  91.0      83.0
# 5                17.0  2015-08-30                  2023  76.0      86.0
#
#    passing  dribbling  defending  physic  attacking_crossing  \
# 0     92.0       96.0       39.0    66.0                  88
# 1     82.0       89.0       35.0    78.0                  84
# 2     87.0       95.0       32.0    58.0                  87
# 4     86.0       94.0       35.0    66.0                  81
# 5     92.0       86.0       61.0    78.0                  93
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 4                   84                          61                       89
# 5                   82                          55                       92
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 4                 83               95           83                 79
# 5                 82               86           85                 83
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 4                  83                  94                     94
# 5                  91                  91                     77
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 4                     88                95                  90
# 5                     76                78                  91
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 4                94                82             56             84
# 5                76                91             63             89
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 4              63                80                    54
# 5              74                90                    76
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 4                       41                     87                89
# 5                       61                     88                94
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 4                   88                   91                 34
# 5                   79                   91                 68
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_reflexes  \
# 0                         37                        26                     8
# 1                         32                        24                    11
# 2                         26                        29                    11
# 4                         27                        22                     8
# 5                         58                        51                    13
#
#    ls  st  rs  lw  lf  cf  rf  rw lam cam ram  lm lcm  cm rcm  rm lwb ldm cdm  \
# 0  89  89  89  93  93  93  93  93  93  93  93  92  87  87  87  92  68  66  66
# 1  91  91  91  89  90  90  90  89  88  88  88  88  81  81  81  88  65  61  61
# 2  84  84  84  90  89  89  89  90  90  90  90  89  82  82  82  89  66  61  61
# 4  83  83  83  89  88  88  88  89  89  89  89  89  83  83  83  89  66  63  63
# 5  82  82  82  87  87  87  87  87  88  88  88  88  87  87  87  88  77  77  77
#
#   rdm rwb  lb lcb  cb rcb  rb
# 0  66  68  63  52  52  52  63
# 1  61  65  61  53  53  53  61
# 2  61  66  61  46  46  46  61
# 4  63  66  61  49  49  49  61
# 5  77  77  73  66  66  66  73

# %%
# check for minimum value in "overall" column.

data['overall'].min()
# Out:
# 48

# %%
# Cluster analysis:

data.columns
# Out:
# Index(['short_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club',
#        'overall', 'potential', 'value_eur', 'wage_eur', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'body_type',
#        'release_clause_eur', 'team_position', 'team_jersey_number', 'joined',
#        'contract_valid_until', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_reflexes', 'ls', 'st', 'rs',
#        'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm',
#        'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
#        'rcb', 'rb'],
#       dtype='object')

# %%
# Select some columns:
data = data[['short_name','age','overall','value_eur','international_reputation','skill_moves','pace','shooting','passing','dribbling','physic']]

# %%
# In "overall" column, fetch all the rows with values > 50.

data = data[data.overall>50]

# %%
names = data.short_name.tolist()

# %%
# drop short name column.

data = data.drop("short_name",axis=1)

# %%
data.head()
# Out:
#    age  overall  value_eur  international_reputation  skill_moves  pace  \
# 0   32       94   95500000                         5            4  87.0
# 1   34       93   58500000                         5            5  90.0
# 2   27       92  105500000                         5            5  91.0
# 4   28       91   90000000                         4            4  91.0
# 5   28       91   90000000                         4            4  76.0
#
#    shooting  passing  dribbling  physic
# 0      92.0     92.0       96.0    66.0
# 1      93.0     82.0       89.0    78.0
# 2      85.0     87.0       95.0    58.0
# 4      83.0     86.0       94.0    66.0
# 5      86.0     92.0       86.0    78.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df = scaler.fit_transform(data)

# %%
df
# Out:
# array([[6.15384615e-01, 1.00000000e+00, 9.05213270e-01, ...,
#         1.00000000e+00, 1.00000000e+00, 6.19047619e-01],
#        [6.92307692e-01, 9.76744186e-01, 5.54502370e-01, ...,
#         8.52941176e-01, 9.04109589e-01, 8.09523810e-01],
#        [4.23076923e-01, 9.53488372e-01, 1.00000000e+00, ...,
#         9.26470588e-01, 9.86301370e-01, 4.92063492e-01],
#        ...,
#        [7.69230769e-02, 0.00000000e+00, 2.84360190e-04, ...,
#         4.88732009e-01, 5.41528559e-01, 6.01217107e-01],
#        [4.23076923e-01, 0.00000000e+00, 3.79146919e-04, ...,
#         3.08823529e-01, 3.01369863e-01, 5.87301587e-01],
#        [4.23076923e-01, 0.00000000e+00, 3.79146919e-04, ...,
#         2.79411765e-01, 3.83561644e-01, 4.28571429e-01]])

# %%
data = pd.DataFrame(df,columns=data.columns)
data
# Out:
#             age   overall  value_eur  international_reputation  skill_moves  \
# 0      0.615385  1.000000   0.905213                      1.00         0.75
# 1      0.692308  0.976744   0.554502                      1.00         1.00
# 2      0.423077  0.953488   1.000000                      1.00         1.00
# 3      0.461538  0.930233   0.853081                      0.75         0.75
# 4      0.461538  0.930233   0.853081                      0.75         0.75
# ...         ...       ...        ...                       ...          ...
# 17400  0.269231  0.000000   0.000474                      0.00         0.25
# 17401  0.192308  0.000000   0.000474                      0.00         0.25
# 17402  0.076923  0.000000   0.000284                      0.00         0.00
# 17403  0.423077  0.000000   0.000379                      0.00         0.25
# 17404  0.423077  0.000000   0.000379                      0.00         0.25
#
#            pace  shooting   passing  dribbling    physic
# 0      0.875000  0.987179  1.000000   1.000000  0.619048
# 1      0.916667  1.000000  0.852941   0.904110  0.809524
# 2      0.930556  0.897436  0.926471   0.986301  0.492063
# 3      0.930556  0.871795  0.911765   0.972603  0.619048
# 4      0.722222  0.910256  1.000000   0.863014  0.809524
# ...         ...       ...       ...        ...       ...
# 17400  0.666667  0.397436  0.397059   0.452055  0.412698
# 17401  0.569444  0.307692  0.367647   0.328767  0.460317
# 17402  0.606957  0.478183  0.488732   0.541529  0.601217
# 17403  0.458333  0.269231  0.308824   0.301370  0.587302
# 17404  0.750000  0.423077  0.279412   0.383562  0.428571
#
# [17405 rows x 10 columns]

# %% [markdown]
# # 7. Model Creation:
# ### 7.1. K-Means Algorithem:-

# %%
# Importing K_means:

from sklearn.cluster import KMeans

# Initialize the model:
model = KMeans(n_clusters=6, random_state=10)

# Training the model:
model.fit(data)
# Out:
# KMeans(n_clusters=6, random_state=10)

# %%
# centroids - cluster centers.
# no of clusters == no of centroieds

model.cluster_centers_
# Out:
# array([[2.48554183e-01, 3.36394500e-01, 1.24078770e-02, 3.64963504e-04,
#         5.07572993e-01, 7.04947283e-01, 5.39172749e-01, 5.17104981e-01,
#         6.15108489e-01, 4.67622523e-01],
#        [4.37669566e-01, 4.60930715e-01, 3.23493761e-02, 7.90975104e-03,
#         5.20811722e-01, 6.70398225e-01, 6.15820167e-01, 6.02780998e-01,
#         6.47317115e-01, 6.59574030e-01],
#        [5.04778490e-01, 3.95079167e-01, 1.77551744e-02, 2.32606295e-02,
#         2.17076201e-01, 5.31708727e-01, 4.47476960e-01, 4.89088173e-01,
#         5.07059491e-01, 6.97310468e-01],
#        [3.18691936e-01, 2.80597686e-01, 7.52105227e-03, 1.32850242e-03,
#         2.51328502e-01, 4.55065754e-01, 1.97095256e-01, 2.70545610e-01,
#         3.00972801e-01, 6.58615137e-01],
#        [1.97600304e-01, 1.97826399e-01, 3.67510709e-03, 5.55111512e-17,
#         2.11405672e-01, 6.15875692e-01, 4.24111857e-01, 4.19788432e-01,
#         5.01999682e-01, 5.08842679e-01],
#        [4.91416775e-01, 6.43213770e-01, 1.44222472e-01, 3.05790960e-01,
#         6.07344633e-01, 6.56478866e-01, 7.12830170e-01, 7.28024261e-01,
#         7.40667647e-01, 6.82046453e-01]])

# %%
model.labels_
# Out:
# array([5, 5, 5, ..., 4, 3, 4])

# %%
from sklearn import preprocessing
r_scaler = preprocessing.RobustScaler()

# %%
data_model_robust = r_scaler.fit_transform(data)
data_model_final = pd.DataFrame(data_model_robust)

# %%
data_model_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17405 entries, 0 to 17404
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       17405 non-null  float64
#  1   1       17405 non-null  float64
#  2   2       17405 non-null  float64
#  3   3       17405 non-null  float64
#  4   4       17405 non-null  float64
#  5   5       17405 non-null  float64
#  6   6       17405 non-null  float64
#  7   7       17405 non-null  float64
#  8   8       17405 non-null  float64
#  9   9       17405 non-null  float64
# dtypes: float64(10)
# memory usage: 1.3 MB

# %%
data_model_final.head()
# Out:
#           0         1          2     3    4         5         6         7  \
# 0  1.166667  3.111111  53.394366  1.00  2.0  1.461538  2.052632  2.674325
# 1  1.500000  3.000000  32.549296  1.00  3.0  1.692308  2.105263  1.905094
# 2  0.333333  2.888889  59.028169  1.00  3.0  1.769231  1.684211  2.289709
# 3  0.500000  2.777778  50.295775  0.75  2.0  1.769231  1.578947  2.212786
# 4  0.500000  2.777778  50.295775  0.75  2.0  0.615385  1.736842  2.674325
#
#           8         9
# 0  3.000000  0.083333
# 1  2.363636  1.083333
# 2  2.909091 -0.583333
# 3  2.818182  0.083333
# 4  2.090909  1.083333

# %% [markdown]
# ### 7.2. Principal Component Analysis Algorithem:-

# %%
from sklearn.decomposition import PCA
pca = PCA()
principalcomponents = pca.fit_transform(data_model_final)

# %%
exp_var = pca.explained_variance_ratio_
exp_var
# Out:
# array([7.18331297e-01, 1.13467416e-01, 7.27602126e-02, 2.96358996e-02,
#        2.09019452e-02, 1.92951828e-02, 1.31389450e-02, 7.42346015e-03,
#        4.70194861e-03, 3.43693587e-04])

# %%
# fetching the optimum value of principal components using PCA

plt.figure(figsize=(13,5))
plt.plot(range(0,10), pca.explained_variance_ratio_.cumsum(), marker='o',linestyle='dotted')
plt.xlabel('Number of Components')
plt.ylabel('Variance in %') # for each component
plt.title('Expalined Variance by Componenets')
plt.show()

# %%
pca = PCA(n_components=5)
new_data = pca.fit_transform(data_model_final)
new_data_pca = pd.DataFrame(new_data)
new_data_pca.columns=['P1','P2','P3','P4','P5']
new_data_pca.head()
# Out:
#           P1        P2        P3        P4        P5
# 0  51.821617  7.830923  4.220269  1.691645  2.258821
# 1  31.879068  2.961696  1.356679  0.262116  0.120796
# 2  57.123052  9.158750  6.050974  2.052872  1.475707
# 3  48.673399  7.523012  4.626192  1.163200  1.856428
# 4  48.637354  8.266657  3.520438  1.466544  1.540184

# %% [markdown]
# ## K Means Clustering Model Building

# %% [markdown]
# **Elbow Method to Determine the Optimal Number of Clusters**
#
# >The Elbow method involves changing the number of clusters (K) from 1 to 10. For each value of K, we compute WCSS (Within-Cluster Sum of Squares), which represents the total squared distances between each data point and the centroid within a cluster.

# %%
from sklearn.cluster import KMeans
WCSS = [] # Within cluster sum of square:
for k in range(2,11):
    kmeans =KMeans(n_clusters=k, random_state=5)
    kmeans.fit(new_data_pca)
    WCSS.append(kmeans.inertia_)

# %%
WCSS
# Out:
# [136992.57482046448,
#  93604.37766132782,
#  74972.83455793485,
#  62416.92483915755,
#  53718.23147465239,
#  48161.888182276045,
#  42849.26539138991,
#  39312.01228912247,
#  36577.64611152948]

# %%
plt.figure(figsize=(15,7))
plt.plot(list(range(1,10)),WCSS)
plt.xlabel("NO. of clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# The Silhouette score is a measure used to assess the quality of a clustering technique, with values ranging from -1 to 1. A score of 1 indicates that the clusters are well separated and distinctly defined.

# %%
x=data
model=KMeans(n_clusters=2,random_state=10)
model.fit(x)
# Out:
# KMeans(n_clusters=2, random_state=10)

# %%
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn import datasets
from sklearn.metrics import silhouette_score

# %%
# Silhouette Score for various clusters:
range_n_clusters = [2,3,4,5,6,7,8,9,10]
silhouette_scr = []
for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters)
    kmeans.fit_transform(new_data_pca)
    cluster_labels = kmeans.labels_
    silhouette_scr.append(silhouette_score(new_data_pca,cluster_labels))

# %%
silhouette_scr
# Out:
# [0.7638743063117723,
#  0.5177391283197508,
#  0.2759255633975579,
#  0.27283403637241677,
#  0.26726787747138464,
#  0.2625459099238874,
#  0.2616988932406651,
#  0.2518810403419402,
#  0.24576419856348372]

# %%
plt.figure(figsize=(14,5))
plt.plot(range_n_clusters,silhouette_scr,color='orange',marker='*',linestyle='dotted')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
# Out:
# Text(0, 0.5, 'Silhouette score')

# %%
new_data_pca.head()
# Out:
#           P1        P2        P3        P4        P5
# 0  51.821617  7.830923  4.220269  1.691645  2.258821
# 1  31.879068  2.961696  1.356679  0.262116  0.120796
# 2  57.123052  9.158750  6.050974  2.052872  1.475707
# 3  48.673399  7.523012  4.626192  1.163200  1.856428
# 4  48.637354  8.266657  3.520438  1.466544  1.540184

# %%
kmeans_pca = KMeans(n_clusters=6, random_state=42).fit(new_data_pca)
kmeans_pca_clustered =pd.DataFrame(new_data_pca.copy())
kmeans_pca_clustered.loc[:,'Cluster'] = kmeans_pca.labels_

# %%
kmeans_pca_clustered.shape
# Out:
# (17405, 6)

# %%
import seaborn as sns
fig1, (axes) = plt.subplots(2,1,figsize=(8,10))


scat_1=sns.scatterplot (x='P1' , y='P2', data=kmeans_pca_clustered,hue='Cluster',  palette='Set1', ax=axes[0], legend='full')

scat_2=sns.scatterplot (x='P3' , y='P1', data=kmeans_pca_clustered,hue='Cluster', palette='Set1', ax=axes[1], legend='full')
plt.show()

# %%
import seaborn as sns
fig1, (axes) = plt.subplots(2,1,figsize=(8,10))


scat_1=sns.scatterplot (x='P1' , y='P4', data=kmeans_pca_clustered,hue='Cluster',  palette='Set1', ax=axes[0], legend='full')

scat_2=sns.scatterplot (x='P5' , y='P1', data=kmeans_pca_clustered,hue='Cluster', palette='Set1', ax=axes[1], legend='full')
plt.show()

# %%
import seaborn as sns
fig1, (axes) = plt.subplots(2,1,figsize=(8,10))


scat_1=sns.scatterplot (x='P3' , y='P2', data=kmeans_pca_clustered,hue='Cluster',  palette='Set1', ax=axes[0], legend='full')

scat_2=sns.scatterplot (x='P2' , y='P4', data=kmeans_pca_clustered,hue='Cluster', palette='Set1', ax=axes[1], legend='full')
plt.show()

# %%
import seaborn as sns
fig1, (axes) = plt.subplots(2,1,figsize=(8,10))


scat_1=sns.scatterplot (x='P5' , y='P2', data=kmeans_pca_clustered,hue='Cluster',  palette='Set1', ax=axes[0], legend='full')

scat_2=sns.scatterplot (x='P3' , y='P4', data=kmeans_pca_clustered,hue='Cluster', palette='Set1', ax=axes[1], legend='full')
plt.show()

# %%
import seaborn as sns
fig1, (axes) = plt.subplots(2,1,figsize=(8,10))


scat_1=sns.scatterplot (x='P3' , y='P5', data=kmeans_pca_clustered,hue='Cluster',  palette='Set1', ax=axes[0], legend='full')

scat_2=sns.scatterplot (x='P4' , y='P5', data=kmeans_pca_clustered,hue='Cluster', palette='Set1', ax=axes[1], legend='full')
plt.show()

# %% [markdown]
# ### 1. Global Trends in Player Production:
# England, Germany, and Spain stand out as the top countries producing football players in the FIFA 20 game, significantly leading over other nations. This dominance reflects their strong footballing cultures and deep-rooted traditions.
#
# ### 2. Age-Related Performance Trends:
# Player performance tends to hit its peak around age 30, followed by a slow decline. However, there's an interesting rebound in performance in the late 30s, likely due to the impact of experienced veteran players. This information is crucial for clubs and teams focused on player scouting and development.
#
# ### 3. Wage Patterns by Position:
# Among offensive roles, left-wingers tend to earn the most, with strikers and right-wingers close behind. Understanding these wage patterns can significantly affect how clubs approach player recruitment and salary negotiations.
#
# ### 4. Strengths of Goalkeepers:
# Goalkeepers excel in key areas like handling and reflexes, which are vital for their position. Despite their skills, their salaries are usually lower compared to outfield players.
#
# ### 5. Release Clauses vs. Player Values:
# Release clauses are generally set higher than reported player values, highlighting the extra costs involved in player transfers. This knowledge is crucial for clubs and agents during contract discussions.
#
# ### 6. Player Clustering Analysis:
# Clustering analysis helps to identify distinct groups of players based on various attributes. This categorization can assist clubs in targeting players that best meet their team needs.
#
# ### 7. Effective Player Development:
# Insights into when players typically peak and decline are valuable for clubs managing player development programs. Balancing youth and experience becomes a key component in creating a successful team strategy.
#
# ## Overall Significance:
# Analyzing FIFA 20 player data provides valuable insights that benefit football clubs, agents, players, and fans within the virtual football world. It serves as a guide for improving talent scouting, recruiting strategies, and contract negotiations. Additionally, it enhances fan engagement by offering a deeper understanding of player characteristics and market trends in the FIFA 20 environment.
